# %% [markdown]
# 8E1.  For each of the causal relationships below, name a hypothetical third variable that would lead to an interaction effect.
#
# (1)  Bread dough rises because of yeast.
#
# (2)  Education leads to higher income.
#
# (3)  Gasoline makes a car go

# %% [markdown]
# **AI Prompt**
#
# (1) Bread dough rises because of yeast. yeast and temperature?

# %% [markdown]
# **AI Response**
#
# Excellent thinking! Yes, temperature would create an interaction effect with yeast.
#
# Here's why: Yeast alone doesn't tell the whole story. At very cold temperatures, yeast becomes dormant and won't make dough rise much at all. At moderate warm temperatures, yeast is very active and causes good rising. But at very hot temperatures, yeast dies and again won't cause rising.
#
# So the effect of yeast on dough rising depends on (interacts with) the temperature level.
#
# What about the second one - how education leads to higher income? Can you think of a third variable that might interact with education to affect income?

# %% [markdown]
# **AI Prompt**
#
# (2) Education leads to higher income. sex and education?

# %% [markdown]
# **AI Response**
#
# Yes, that's a very insightful example! Sex (or gender) would indeed create an interaction effect with education.
#
# Here's why this works as an interaction: The relationship between education and income might be different for men versus women. For instance, both men and women might see income increases with more education, but the rate of increase or the absolute levels might differ between the two groups due to various social and economic factors.
#
# So the effect of education on income depends on (interacts with) gender.
#
# Now for the third one - gasoline makes a car go. What third variable do you think might interact with gasoline to affect how well a car runs?

# %% [markdown]
# **AI Prompt**
#
# (3) Gasoline makes a car go - gas and tire traction?

# %% [markdown]
# **AI Response**
#
# That's a really good example! Yes, tire traction would create an interaction effect with gasoline.
#
# Here's why: Gasoline provides the energy to make the car go, but if you have no tire traction (like on ice or in deep mud), even a full tank of gas won't make the car move effectively. Good traction allows the gasoline's power to be transferred to actual movement, while poor traction means the wheels just spin without the car going anywhere.
#
# So the effect of gasoline on making a car go depends on (interacts with) the level of tire traction.
#
# You did great with all three examples! You really understand how interaction effects work - when the effect of one variable depends on the level of another variable.
#
# Are there any questions about interaction effects, or would you like to explore another concept?

# %% [markdown]
# 8E2.  Which of the following explanations invokes an interaction?
#
# (1)  Caramelizing onions requires cooking over low heat and making sure the onions do not dry out.
#
# (2)  A car will go faster when it has more cylinders or when it has a better fuel injector.
#
# (3)  Most people acquire their political beliefs from their parents, unless they get them instead from their friends.
#
# (4)  Intelligent animal species tend to be either highly social or have manipulative appendages (hands, tentacles, etc.).

# %% [markdown]
# **AI Prompt**
#
# (1) Caramelizing onions requires cooking over low heat and making sure the onions do not dry out.  heat and onion dryness?

# %% [markdown]
# **AI Response**
#
# Good thinking! You're on the right track, but let's think about this more carefully.
#
# For an interaction effect, we need the effect of one variable to depend on the level of another variable.
#
# In this caramelizing onions example, both low heat AND not drying out are needed together for successful caramelization. But does the statement suggest that the effect of heat depends on moisture level, or vice versa?
#
# The statement seems to say you need both conditions, but it doesn't clearly indicate that the effect of one depends on the other. It's more like both are necessary requirements.
#
# What do you think - does this sound like a true interaction where one variable's effect changes based on the other, or just two separate requirements that both need to be met?

# %% [markdown]
# **AI Prompt**
#
# separate

# %% [markdown]
# **AI Response**
#
# Exactly right! This is describing two separate requirements that both need to be met, rather than a true interaction effect.
#
# Now let's look at option (2): "A car will go faster when it has more cylinders or when it has a better fuel injector."
#
# Do you think this one involves an interaction? What's your reasoning?

# %% [markdown]
# **AI Prompt**
#
# A car will go faster when it has more cylinders or when it has a better fuel injector. more cylinders and injector quality makes interaction because better injector could boost speed and having more cylinders adds another boost

# %% [markdown]
# **AI Response**
#
# I can see your reasoning, but let's think about what the statement is actually saying.
#
# The key word here is "or" - the statement says a car will go faster when it has more cylinders OR when it has a better fuel injector. This suggests these are two separate, independent ways to make a car go faster.
#
# For a true interaction, we'd need the effect of one to depend on the other. For example, if the statement said "more cylinders make a bigger difference when you have a better fuel injector," that would be an interaction.
#
# But this statement is listing two separate factors that can each independently make the car faster.
#
# What do you think - does this sound like an interaction or two separate additive effects?

# %% [markdown]
# **AI Prompt**
#
# no

# %% [markdown]
# **AI Response**
#
# Correct! The "or" indicates these are two separate, independent effects rather than an interaction.
#
# Let's move to option (3): "Most people acquire their political beliefs from their parents, unless they get them instead from their friends."
#
# Do you think this one involves an interaction? What stands out to you about how this statement is structured?

# %% [markdown]
# **AI Prompt**
#
# yes, because when they get them from the friends they dont get them from parents?

# %% [markdown]
# **AI Response**
#
# Great observation! You're picking up on something important - the "unless" suggests these sources might work differently depending on circumstances.
#
# But let's think about what makes a true interaction effect. An interaction means the effect of one variable changes based on the level of another variable.
#
# This statement seems to describe two alternative sources (parents vs friends) rather than showing how one variable's effect depends on another variable's level.
#
# What do you think - is this describing how the effect of one factor depends on another, or is it describing two different pathways that don't really interact with each other?

# %% [markdown]
# **AI Prompt**
#
# might be this or other way. it might be that if friends dont provide political beliefs they will get them from parents. if parents have provided them then friends don't provide. I would say that they are not fully independent

# %% [markdown]
# **AI Response**
#
# You're thinking about this really deeply! You're right that these sources aren't fully independent - there's definitely a relationship between them.
#
# But let's focus on what specifically defines an interaction effect: when the effect of one variable depends on the level of another variable.
#
# Think about it this way - is the statement saying that the effect of parents on political beliefs changes depending on what friends do? Or is it more describing which source tends to be dominant?
#
# What's your take - does this fit the specific definition of an interaction where one variable's effect depends on another's level?

# %% [markdown]
# **AI Prompt**
#
# probably not but I would say it has some gray area

# %% [markdown]
# **AI Response**
#
# That's a thoughtful answer! You're right that there's some gray area here - these concepts can have fuzzy boundaries in real-world examples.
#
# Let's look at the last option (4): "Intelligent animal species tend to be either highly social or have manipulative appendages (hands, tentacles, etc.)."
#
# What do you think about this one? Does it describe an interaction effect?

# %% [markdown]
# **AI Prompt**
#
# being social and manipulative appendages seem to interact. if one is missing then the otehr steps in. but they are not interaction again?

# %% [markdown]
# **AI Response**
#
# You're really thinking carefully about this! You've identified that these seem to be alternative pathways to intelligence - if one is missing, the other can compensate.
#
# But you're right to question whether this is a true interaction. This statement is describing two different routes that can each lead to intelligence, rather than showing how the effect of one depends on the level of the other.
#
# So looking back at all four options, which one (if any) do you think best fits the definition of an interaction effect - where the effect of one variable depends on the level of another variable?

# %% [markdown]
# **AI Prompt**
#
# none

# %% [markdown]
# **AI Response**
#
# That's a really good analysis! You've worked through each option carefully and recognized that none of them clearly describes a true interaction effect where one variable's effect depends on the level of another.
#
# You showed good critical thinking by identifying that:
# - Option 1 described two separate requirements
# - Option 2 listed independent factors (connected by "or")
# - Option 3 described alternative pathways rather than interaction
# - Option 4 also described alternative routes to the same outcome
#
# This was a tricky set of examples because they all involved relationships between variables, but not the specific type of relationship that defines an interaction effect.
#
# Do you feel confident about recognizing interaction effects now, or would you like to see some clearer examples of what true interactions look like?

# %% [markdown]
# 8E3.  For each of the explanations in 8E2., write a linear model that expresses the stated relationship.

# %% [markdown]
# **AI Prompt**
#
# (1) caramellizing ~ heat + onion dryness

# %% [markdown]
# **AI Response**
#
# Good start! You've identified the two key variables from the caramelizing onions example.
#
# Let me help you think about the direction of the relationships. The original statement said caramelizing requires "low heat" and making sure onions "do not dry out."
#
# So if we think about it:
# - Lower heat → better caramelizing
# - Less dryness (more moisture) → better caramelizing
#
# How would you adjust your model to show these negative relationships? What signs would you put in front of the variables?

# %% [markdown]
# **AI Prompt**
#
# I could put negative signs but I don't think it matters because model could learn that lower values give better caramellizing

# %% [markdown]
# **AI Response**
#
# That's a really insightful point! You're absolutely right that the model could learn the direction of the relationship from the data.
#
# However, when we're writing linear models to express stated relationships (like in this exercise), it's often clearer to set up the variables so the signs match the intuitive direction of the effect.
#
# You have a couple of options:
# 1. Use negative signs: caramelizing ~ -heat - dryness
# 2. Redefine the variables: caramelizing ~ low_heat + moisture
#
# Which approach do you think would be clearer for expressing this particular relationship?

# %% [markdown]
# **AI Prompt**
#
# (2) speed ~ number_cylinders + fuel_injector_type

# %% [markdown]
# **AI Response**
#
# Good! You've captured the two main variables from the car speed example.
#
# Looking back at the original statement: "A car will go faster when it has more cylinders or when it has a better fuel injector."
#
# Your model shows both variables with positive effects, which matches the "more cylinders = faster" and "better injector = faster" relationships described.
#
# Now let's move to the third one. How would you write a linear model for: "Most people acquire their political beliefs from their parents, unless they get them instead from their friends"?

# %% [markdown]
# **AI Prompt**
#
# (3) political_beliefs = political_beliefs_parents + political_beliefs_friends

# %% [markdown]
# **AI Response**
#
# That's a reasonable start! You've identified the two sources of political beliefs.
#
# But let's think about what the original statement actually said: "Most people acquire their political beliefs from their parents, unless they get them instead from their friends."
#
# The word "unless" and "instead" suggests these aren't simply additive - it's more like one source dominates over the other.
#
# How might you modify your model to better capture this "either/or" relationship rather than both sources contributing at the same time?

# %% [markdown]
# **AI Prompt**
#
# have some indicator variable to detect which source is it coming from

# %% [markdown]
# **AI Response**
#
# Excellent thinking! An indicator variable is a great approach for this "either/or" situation.
#
# How would you set up that indicator variable? What would it represent, and how would you incorporate it into your linear model?

# %% [markdown]
# **AI Prompt**
#
# political_beliefs = source_var x political_beliefs_parents + (1-source_var) x political_beliefs_friends, if one source is parents=1 then source friends=0

# %% [markdown]
# **AI Response**
#
# Perfect! That's an elegant way to model the "either/or" relationship. Your indicator variable approach captures exactly what the original statement described - when source_var = 1, beliefs come from parents, and when source_var = 0, beliefs come from friends.
#
# Now for the last one: "Intelligent animal species tend to be either highly social or have manipulative appendages (hands, tentacles, etc.)."
#
# How would you write a linear model for this relationship?

# %% [markdown]
# **AI Prompt**
#
# intelligent_animal (I dont know what are they trying to predict here) = indicator x socialness + (1-indicator) x manipulative_appendages

# %% [markdown]
# **AI Response**
#
# Great approach! You're using the same indicator variable strategy that worked well for the political beliefs example.
#
# You're right to question what's being predicted - that's a key insight. The original statement suggests that intelligence is the outcome, and it tends to occur when species have either high socialness OR manipulative appendages.
#
# So your model structure makes sense: intelligence ~ indicator × socialness + (1-indicator) × manipulative_appendages
#
# This captures the "either/or" relationship described in the statement. Nice work applying the same logical approach across different examples!
#
# Do you feel comfortable with how to translate these types of stated relationships into linear models?

# %% [markdown]
# 8M1.  Recall the tulips example from the chapter. Suppose another set of treatments adjusted the temperature in the greenhouse over two levels: cold and hot. The data in the chapter were collected at the cold temperature. You find none of the plants grown under the hot temperature developed any blooms at all, regardless of the water and shade levels. Can you explain this result in terms of interactions between water, shade, and temperature?

# %% [markdown]
# I see interaction in  sense that if temperature is low it makes a condition so that things could bloom (if water and shade are ok). but if temp is hot no matter of water and shade it doesnt bloom. interaction would be x (if temp is cold x=1 and else x=0) x*water+x*shade

# %% [markdown]
# 8M2.  Can you invent a regression equation that would make the bloom size zero, whenever the temperature is hot?

# %% [markdown]
# original formula is $$
# B_i \sim \text{Normal}(\mu_i, \sigma)
# $$
#
# $$
# \mu_i = \alpha + \beta_W W_i + \beta_S S_i + \beta_{WS} W_i S_i
# $$
#
# new formula could be \begin{align*}
# B_i &\sim \text{Normal}(\mu_i, \sigma) \\
# \mu_i &= Z_i \left( \alpha + \beta_W W_i + \beta_S S_i + \beta_{WS} W_i S_i \right)
# \end{align*}

# %% [markdown]
# 8M3.  In parts of North America, ravens depend upon wolves for their food. This is because ravens are carnivorous but cannot usually kill or open carcasses of prey. Wolves however can and do kill and tear open animals, and they tolerate ravens co-feeding at their kills. This species relationship is generally described as a “species interaction.” Can you invent a hypothetical set of data on raven population size in which this relationship would manifest as a statistical interaction? Do you think the biological interaction could be linear? Why or why not?

# %% [markdown]
# **AI Prompt**
#
# data would be so that when wolves would be near ravens their population woudl be bigger ( the more wolves/packs). wolve population desnity doesnt depend on the raven population. interaction would not be linear. ravens depend on wolves but don't benfit wolves much. so more or less ravens doesnt effect wolves population

# %% [markdown]
# **AI Response**
#
# You've got some really good insights here! Let me break down what you've identified:
#
# 1. **Directional relationship**: You're absolutely right that ravens depend on wolves, but wolves don't really benefit from ravens - this is called a commensal relationship in biology.
#
# 2. **Non-linearity**: Great point! You're thinking that the relationship wouldn't be linear.
#
# Let me ask you to think a bit deeper about the statistical interaction part. For a statistical interaction, we need the effect of one variable to depend on the level of another variable.
#
# What other variable besides wolf population might affect raven population? And how might the effect of wolves on ravens change depending on that other variable?
#
# For example, what about food scarcity in the environment, or season, or territory size?
