# %% [markdown]
# 4E1.  In the model definition below, which line is the likelihood? y
# $$
# \begin{aligned}
# y_i &\sim \text{Normal}(\mu, \sigma) \\
# \mu &\sim \text{Normal}(0, 10) \\
# \sigma &\sim \text{Exponential}(1)
# \end{aligned}
# $$

# %% [markdown]
# **AI Prompt**
#
# I think first line is likelihood: y_i &\sim \text{Normal}(\mu, \sigma)

# %% [markdown]
# **AI Response**
#
# Exactly right! The first line `y_i ~ Normal(μ, σ)` is indeed the likelihood.
#
# This line describes how your observed data `y_i` is distributed given the parameters μ and σ. It's saying "each data point y_i follows a normal distribution with mean μ and standard deviation σ."
#
# The other two lines are the priors - they specify what you believe about the parameters μ and σ before seeing the data.
#
# Can you tell me what you think the difference is between the likelihood and the priors in terms of what they represent in a Bayesian model?

# %% [markdown]
# 4E2.  In the model definition just above, how many parameters are in the posterior distribution?

# %% [markdown]
# **AI Prompt**
#
# two paramteres mu and sigma?

# %% [markdown]
# **AI Response**
#
# Exactly! There are two parameters in the posterior distribution: μ (mu) and σ (sigma).
#
# The posterior distribution will be a joint distribution over both of these parameters - so it tells us what we believe about both μ and σ after seeing the data, taking into account both the likelihood and the priors.
#
# Do you understand why we need both parameters, or would you like me to explain what each one represents in this normal distribution model?

# %% [markdown]
# 4E3.  Using the model definition above, write down the appropriate form of Bayes’ theorem that includes the proper likelihood and priors.

# %% [markdown]
# P= (likelihood x prior)/(marginal prob)
# P(y|mu, sigma)=(P(sigma, mu | y)x P(y))/(P(mu, sigma))

# %% [markdown]
# **AI Prompt**
#
# am I on the right track?

# %% [markdown]
# **AI Response**
#
# You're getting the idea, but let's clarify the notation a bit. You have the structure right - Bayes' theorem does have that form with likelihood × prior in the numerator.
#
# For this specific model, we want to find the posterior distribution of the parameters (μ and σ) given the data (y). So we're looking for P(μ, σ | y).
#
# Can you try rewriting Bayes' theorem with:
# - The posterior: P(μ, σ | y) on the left side
# - The likelihood: P(y | μ, σ)
# - The prior: P(μ, σ)
#
# What would you put in the denominator?

# %% [markdown]
# **AI Prompt**
#
# P(y)?

# %% [markdown]
# **AI Response**
#
# Exactly! So putting it all together, Bayes' theorem for this model would be:
#
# P(μ, σ | y) = [P(y | μ, σ) × P(μ, σ)] / P(y)
#
# Where:
# - P(μ, σ | y) is the posterior
# - P(y | μ, σ) is the likelihood
# - P(μ, σ) is the prior
# - P(y) is the marginal likelihood (or evidence)
#
# Can you tell me what P(μ, σ) represents in terms of the original model definition? How would we express this joint prior?

# %% [markdown]
# 4E4.  In the model definition below, which line is the linear model?

# %% [markdown]
# $$
# \begin{aligned}
# y_i &\sim \text{Normal}(\mu_i, \sigma) \\
# \mu_i &= \alpha + \beta x_i \\
# \alpha &\sim \text{Normal}(0, 10) \\
# \beta &\sim \text{Normal}(0, 1) \\
# \sigma &\sim \text{Exponential}(2)
# \end{aligned}
# $$

# %% [markdown]
# **AI Prompt**
#
# first line:  y_i &\sim \text{Normal}(\mu_i, \sigma

# %% [markdown]
# **AI Response**
#
# Not quite! The first line is still the likelihood - it describes how the data is distributed.
#
# The linear model is actually the second line: `μᵢ = α + βxᵢ`
#
# This line shows how the mean μᵢ depends linearly on the predictor variable xᵢ, with intercept α and slope β.
#
# Can you see how this differs from the previous model where μ was just a single parameter? What do you think the subscript i represents here?

# %% [markdown]
# **AI Prompt**
#
# data point index?

# %% [markdown]
# **AI Response**
#
# Exactly! The subscript i represents the index for each data point.
#
# So μᵢ is the mean for the i-th observation, and it depends on the corresponding predictor value xᵢ through the linear relationship μᵢ = α + βxᵢ.
#
# This means each data point yᵢ can have its own mean μᵢ, but they're all connected through the same linear relationship with the predictor variable x.
#
# Does this make sense? Can you see how this allows the model to capture a relationship between x and y?

# %% [markdown]
# **AI Prompt**
#
# explain more

# %% [markdown]
# **AI Response**
#
# Sure! Let me break this down further.
#
# In the linear model μᵢ = α + βxᵢ:
#
# - α (alpha) is the intercept - it's the value of μ when x = 0
# - β (beta) is the slope - it tells us how much μ changes when x increases by 1 unit
# - xᵢ is the predictor value for observation i
# - μᵢ is the expected value (mean) for observation i
#
# So if we have data points like (x₁, y₁), (x₂, y₂), etc., each yᵢ comes from a normal distribution centered at μᵢ, but each μᵢ is calculated using the same linear relationship.
#
# For example, if α = 2 and β = 0.5, then:
# - When x₁ = 4, then μ₁ = 2 + 0.5(4) = 4
# - When x₂ = 6, then μ₂ = 2 + 0.5(6) = 5
#
# Does this help clarify how each data point gets its own mean, but they're all connected through the linear relationship?

# %% [markdown]
# **AI Prompt**
#
# but first line is not linear model?

# %% [markdown]
# **AI Response**
#
# You're absolutely right to question this! The first line `y_i ~ Normal(μᵢ, σ)` is NOT the linear model itself.
#
# The first line is the **likelihood** - it describes the probability distribution of the data.
#
# The **linear model** is the second line: `μᵢ = α + βxᵢ`
#
# The linear model defines the relationship between the predictor x and the mean parameter μ. The likelihood then uses that mean in the normal distribution.
#
# Does this distinction make sense? The linear model tells us how to calculate μᵢ, and then the likelihood tells us how yᵢ is distributed around that μᵢ.

# %% [markdown]
# 4E5.  In the model definition just above, how many parameters are in the posterior distribution?

# %% [markdown]
# **AI Prompt**
#
# 3?

# %% [markdown]
# **AI Response**
#
# Exactly right! There are 3 parameters in the posterior distribution: α, β, and σ.
#
# The posterior will be a joint distribution over all three of these parameters - P(α, β, σ | y) - telling us what we believe about the intercept, slope, and standard deviation after seeing the data.
#
# Can you see why we now have one more parameter compared to the earlier model?

# %% [markdown]
# 4M1.  For the model definition below, simulate observed y values from the prior (not the posterior).
#
# $$
# \begin{aligned}
# y_i &\sim \text{Normal}(\mu, \sigma) \\
# \mu &\sim \text{Normal}(0, 10) \\
# \sigma &\sim \text{Exponential}(1)
# \end{aligned}
# $$

# %% [markdown]
# **AI Prompt**
#
# this would mean to sample from normal to get mu values, take sigma for exponential value and use these values to draw samples from normal distributioon?

# %% [markdown]
# **AI Response**
#
# Exactly right! You've got the process correct:
#
# 1. Sample μ from Normal(0, 10)
# 2. Sample σ from Exponential(1)
# 3. Use those sampled μ and σ values to sample y from Normal(μ, σ)
#
# This is called "prior predictive simulation" - you're generating data based on what the model expects before seeing any actual observations.
#
# Would you like to try coding this up? How comfortable are you with sampling from distributions in Python?

# %%
import numpy as np

samples=[]
n=10
for i in range(1000):
    mu = np.random.normal(0, 10)
    sigma=np.random.exponential(1)
    y=np.random.normal(mu, sigma,size=n)
    samples.extend(y)

# %% [markdown]
# **AI Prompt**
#
# like this?

# %% [markdown]
# **AI Response**
#
# Yes, that's exactly right! You've correctly implemented the prior predictive simulation.
#
# Your code:
# 1. Samples μ from Normal(0, 10) ✓
# 2. Samples σ from Exponential(1) ✓
# 3. Uses those to generate n=10 y values from Normal(μ, σ) ✓
# 4. Repeats this 100 times to get a good sample
#
# The `samples` list now contains 1000 y values (100 iterations × 10 samples each) drawn from the prior.
#
# What do you think these samples represent? And would you like to visualize them to see what the prior predicts about the data?

# %%
import matplotlib.pyplot as plt

plt.hist(samples)
# Out:
# (array([  55.,  199.,  717., 1502., 2613., 2645., 1403.,  725.,  130.,
#           11.]),
#  array([-33.91727949, -26.98679339, -20.05630729, -13.12582119,
#          -6.19533509,   0.73515101,   7.66563711,  14.5961232 ,
#          21.5266093 ,  28.4570954 ,  35.3875815 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **AI Prompt**
#
# this shows how prior knowledge simulates the data based on prior knowledge about the parameters?

# %% [markdown]
# **AI Response**
#
# Exactly! You've got it perfectly.
#
# This histogram shows what kind of data your model expects to see *before* observing any actual data. It's based purely on your prior beliefs about μ and σ.
#
# Notice how the distribution is roughly centered around 0 (because μ has mean 0) but quite spread out. This reflects the uncertainty in your priors.
#
# What do you think would happen to this distribution if you changed the priors? For example, what if μ ~ Normal(0, 1) instead of Normal(0, 10)?

# %% [markdown]
# 4M2.  Translate the model just above into a quap formula.

# %% [markdown]
# **AI Prompt**
#
# what does that mean?

# %% [markdown]
# **AI Response**
#
# Good question! "quap" refers to quadratic approximation - it's a method for approximating the posterior distribution.
#
# Instead of finding the exact posterior (which can be complex), quap finds the peak of the posterior and approximates it as a multivariate normal distribution around that peak.
#
# The "quap formula" means writing the model in a specific format that the quap function can understand, typically using the `alist()` function in R or similar syntax.
#
# Are you familiar with the R programming language and the rethinking package, or are you working in a different environment?

# %% [markdown]
# **AI Prompt**
#
# can I do similar thing in python?

# %% [markdown]
# **AI Response**
#
# Yes! There are several Python libraries that can do similar Bayesian inference. The most popular ones are:
#
# - **PyMC** - very user-friendly for Bayesian modeling
# - **Stan** (via PyStan) - powerful and flexible
# - **scipy.optimize** - for simple maximum likelihood estimation
#
# For the quadratic approximation specifically, you could use scipy's optimization functions to find the posterior mode and approximate the covariance.
#
# Which approach interests you most? Or would you like to see how to set up this same model in one of these Python frameworks?

# %% [markdown]
# **AI Prompt**
#
# lets use scipy.optimize

# %% [markdown]
# **AI Response**
#
# Great choice! With scipy.optimize, we'll need to define a function that calculates the negative log-likelihood (since optimizers minimize by default, but we want to maximize likelihood).
#
# For your model:
# - y_i ~ Normal(μ, σ)
# - μ ~ Normal(0, 10)
# - σ ~ Exponential(1)
#
# The log-likelihood would combine the data likelihood plus the log-priors.
#
# Do you want to try writing the negative log-likelihood function yourself, or would you like me to show you how to set it up?

# %% [markdown]
# **AI Prompt**
#
# show how to set up

# %% [markdown]
# **AI Response**
#
# Here's how to set up the negative log-likelihood function:
#
# ```python
# import numpy as np
# from scipy import stats
#
# def neg_log_likelihood(params, y_data):
#     mu, sigma = params
#
#     # Data likelihood: sum of log probabilities
#     data_ll = np.sum(stats.norm.logpdf(y_data, mu, sigma))
#
#     # Prior for mu: Normal(0, 10)
#     mu_prior = stats.norm.logpdf(mu, 0, 10)
#
#     # Prior for sigma: Exponential(1)
#     sigma_prior = stats.expon.logpdf(sigma, scale=1)
#
#     # Return negative (since we want to minimize)
#     return -(data_ll + mu_prior + sigma_prior)
# ```
#
# This function takes the parameters [μ, σ] and your observed data, then calculates the negative log-posterior.
#
# Do you understand each part? Would you like to try using this with scipy.optimize.minimize next?

# %%
import numpy as np
from scipy import stats

def neg_log_likelihood(params, y_data):
    mu, sigma = params
    
    # Data likelihood: sum of log probabilities
    data_ll = np.sum(stats.norm.logpdf(y_data, mu, sigma))
    
    # Prior for mu: Normal(0, 10)
    mu_prior = stats.norm.logpdf(mu, 0, 10)
    
    # Prior for sigma: Exponential(1)
    sigma_prior = stats.expon.logpdf(sigma, scale=1)
    
    # Return negative (since we want to minimize)
    return -(data_ll + mu_prior + sigma_prior)

# %% [markdown]
# **AI Prompt**
#
# there is no marginal probabliity?

# %% [markdown]
# **AI Response**
#
# Good observation! You're right - there's no marginal probability P(y) in this function.
#
# In maximum likelihood estimation and MAP (maximum a posteriori) estimation, we don't need the marginal probability because it's constant with respect to the parameters we're optimizing over.
#
# Since we're just finding the peak of the posterior (the mode), we can ignore the normalizing constant P(y). It doesn't affect where the maximum occurs.
#
# Does this make sense? The marginal probability would only matter if we needed the actual posterior probabilities, not just the parameter values that maximize them.

# %% [markdown]
# **AI Prompt**
#
# show how ot use scipy otpimize

# %% [markdown]
# **AI Response**
#
# Here's how to use scipy.optimize with your function:
#
# ```python
# from scipy.optimize import minimize
#
# # You'll need some observed data first
# y_observed = np.array([1.2, 0.8, 2.1, -0.5, 1.8])  # example data
#
# # Initial guess for [mu, sigma]
# initial_guess = [0, 1]
#
# # Optimize
# result = minimize(neg_log_likelihood, initial_guess, args=(y_observed,))
# ```
#
# Do you have some actual data to use, or would you like to generate some sample data first? Also, what do you think the `args=(y_observed,)` part does?

# %%
from scipy.optimize import minimize

# You'll need some observed data first
y_observed = np.array([1.2, 0.8, 2.1, -0.5, 1.8])  # example data

# Initial guess for [mu, sigma]
initial_guess = [0, 1]

# Optimize
result = minimize(neg_log_likelihood, initial_guess, args=(y_observed,))

# %%
result
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 10.7295559832907
#         x: [ 1.078e+00  8.426e-01]
#       nit: 9
#       jac: [-2.742e-06 -1.192e-07]
#  hess_inv: [[ 1.391e-01 -2.334e-04]
#             [-2.334e-04  5.676e-02]]
#      nfev: 36
#      njev: 12

# %% [markdown]
# **AI Prompt**
#
# what is initial guess? starting values?

# %% [markdown]
# **AI Response**
#
# Exactly! The initial guess provides starting values for the optimization algorithm.
#
# The optimizer needs somewhere to begin searching for the minimum. It starts at [μ=0, σ=1] and then iteratively adjusts these values to find the parameter values that minimize the negative log-likelihood.
#
# Looking at your result, what do you think the final estimates are for μ and σ? (Hint: look at the 'x' values in the output)

# %% [markdown]
# 4M3.  Translate the quap model formula below into a mathematical model definition.
# y ~ dnorm( mu , sigma ),
# mu <- a + b*x,
# a ~ dnorm( 0 , 10 ),
# b ~ dunif( 0,1),
# sigma ~ dexp( 1 )

# %% [markdown]
# yi ~Normal(mui, sigma)
#
# mui=a+bxi
#
# a~Normal(0,10)
#
# b~Uniform(0,1)
#
# sigma~Exponential(1)

# %% [markdown]
# **AI Prompt**
#
# like that?

# %% [markdown]
# **AI Response**
#
# Perfect! You've correctly translated the quap formula into mathematical notation:
#
# - y_i ~ Normal(μ_i, σ) - the likelihood
# - μ_i = a + bx_i - the linear model
# - a ~ Normal(0, 10) - prior for intercept
# - b ~ Uniform(0, 1) - prior for slope
# - σ ~ Exponential(1) - prior for standard deviation
#
# You got all the distributions and relationships right. Notice how this is a linear regression model - each observation has its own mean μ_i that depends on the predictor x_i.
#
# What do you think the Uniform(0,1) prior on b tells us about our beliefs regarding the slope?

# %% [markdown]
# 4M4.  A sample of students is measured for height each year for 3 years. After the third year, you want to fit a linear regression predicting height using year as a predictor. Write down the mathematical model definition for this regression, using any variable names and priors you choose. Be prepared to defend your choice of priors.

# %% [markdown]
# height ~Normal(mu_i, sigma)
# mu_i=a+bx_i
# a~Normal(0,10)
# b~Uniform(0,1)
# sigma~Exponential(1)

# %% [markdown]
# **AI Prompt**
#
# I think I should change so that year changes the intercept? each year might have different baseline?

# %% [markdown]
# **AI Response**
#
# That's an interesting thought! But let me clarify what your current model does:
#
# In your model `μ_i = a + bx_i`, where x_i is the year:
# - `a` is the baseline height at year 0
# - `b` is how much height increases per year
# - Each student-year observation gets its own predicted height μ_i
#
# This actually captures growth over time. But I'm curious about your priors - do you think a Uniform(0,1) prior on `b` makes sense for height growth per year?
#
# What units do you think height and year are measured in, and how much would you expect a student to grow per year?

# %% [markdown]
# **AI Prompt**
#
# depends on the class they are, earlier classes growth might be bigger. uniform is not the best. I think it could be normal?

# %% [markdown]
# **AI Response**
#
# Exactly! You're thinking like a good statistician. A Normal prior for `b` would be much more reasonable than Uniform(0,1).
#
# You're absolutely right that growth rates depend on age - younger students typically grow faster than older ones.
#
# If we're measuring height in centimeters and these are, say, middle school students, what do you think would be a reasonable mean and standard deviation for the Normal prior on `b`?
#
# How many cm per year might a typical student in this age range grow?

# %% [markdown]
# **AI Prompt**
#
# maybe up to 10cm?

# %% [markdown]
# **AI Response**
#
# That sounds reasonable! Around 10cm per year is definitely possible for growing students.
#
# So you might use something like `b ~ Normal(5, 3)` - meaning you expect around 5cm growth per year on average, but allowing for quite a bit of variation (some students might grow 2cm, others might grow 8-10cm).
#
# What do you think about your prior for the intercept `a`? If year 0 represents the first measurement year, what would be a reasonable prior for the baseline height?

# %% [markdown]
# **AI Prompt**
#
# height of the students in the that year. maybe like 130 cm for youngsters?

# %% [markdown]
# **AI Response**
#
# Good thinking! If these are younger students starting around 130cm, then `a ~ Normal(130, 20)` might make sense - centered at 130cm with enough spread to account for natural variation in student heights.
#
# So your revised model would be:
# - height_i ~ Normal(μ_i, σ)
# - μ_i = a + b × year_i
# - a ~ Normal(130, 20)
# - b ~ Normal(5, 3)
# - σ ~ Exponential(1)
#
# Does this seem more reasonable than your original priors? What do you think about the σ prior - is Exponential(1) appropriate for the variability around the growth trend?

# %% [markdown]
# **AI Prompt**
#
# have normal here too?

# %% [markdown]
# **AI Response**
#
# That's a great question! You could use a Normal prior for σ, but there's an important constraint to consider.
#
# Since σ represents standard deviation, it must be positive. The Exponential distribution naturally ensures this constraint, while a Normal distribution could give negative values.
#
# If you wanted to use Normal, you'd need a half-Normal (truncated at zero) or put the Normal on a positive range.
#
# What do you think - does the constraint that σ > 0 make sense for measuring variability in heights?

# %% [markdown]
# **AI Prompt**
#
# it does make sense. what do you suggest?

# %% [markdown]
# **AI Response**
#
# For σ, I'd suggest sticking with the Exponential(1) prior you had originally. It's a common and sensible choice because:
#
# 1. It keeps σ positive (as required)
# 2. It has a reasonable scale for height measurements
# 3. It's commonly used in Bayesian regression
#
# However, if the scale doesn't seem right for your data, you could adjust it - like Exponential(0.1) for tighter variability or Exponential(2) for more spread.
#
# What do you think about keeping Exponential(1) for σ in your height model?

# %% [markdown]
# 4M5.  Now suppose I remind you that every student got taller each year. Does this information lead you to change your choice of priors? How?

# %% [markdown]
# **AI Prompt**
#
# maybe make b std smaller because more certain of growth? maybe even increse 5 a bit?

# %% [markdown]
# **AI Response**
#
# Excellent reasoning! Yes, if every student got taller each year, that gives us much stronger prior information.
#
# You're right on both counts:
# - Making the standard deviation smaller (like `b ~ Normal(5, 1)` or even smaller) because we're more certain about positive growth
# - Maybe increasing the mean slightly if you think the growth rate might be higher given that ALL students grew
#
# You could even consider a prior that ensures b is always positive, since negative growth apparently didn't happen in this dataset.
#
# What do you think about using something like `b ~ Normal(6, 1)` to reflect both the higher expected growth and the increased certainty?

# %% [markdown]
# 4M6.  Now suppose I tell you that the variance among heights for students of the same age is never more than 64cm. How does this lead you to revise your priors?

# %% [markdown]
# **AI Prompt**
#
# review the sigma?

# %% [markdown]
# **AI Response**
#
# Exactly! If the variance is never more than 64cm², then the standard deviation σ is never more than √64 = 8cm.
#
# This means your current prior `σ ~ Exponential(1)` might allow values that are too large, since an Exponential(1) can generate values well above 8.
#
# How would you adjust the σ prior to respect this constraint that σ ≤ 8?

# %% [markdown]
# **AI Prompt**
#
# what values does  Exponential(1) produce?

# %% [markdown]
# **AI Response**
#
# Good question! An Exponential(1) distribution has most of its probability mass near 0, but it has a long tail that can produce quite large values.
#
# - About 63% of values are below 1
# - About 95% of values are below 3
# - But there's still a small probability of getting values like 5, 8, or even larger
#
# Since you need σ ≤ 8, you could use a smaller rate parameter like Exponential(0.2) or Exponential(0.5) to keep most values well below 8.
#
# What do you think would work better for your constraint?

# %% [markdown]
# **AI Prompt**
#
# Exponential(0.5)?

# %% [markdown]
# **AI Response**
#
# Good choice! Exponential(0.5) would give you:
# - About 63% of values below 2
# - About 95% of values below 6
# - Very low probability of exceeding 8
#
# This respects your constraint much better than Exponential(1).
#
# Alternatively, you could use a uniform prior like Uniform(0, 8) to strictly enforce the upper bound. Which approach do you prefer - the softer constraint with Exponential(0.5) or the hard constraint with Uniform(0, 8)?

# %% [markdown]
# 4M7.  Refit model m4.3 from the chapter, but omit the mean weight xbar this time. Compare the new model’s posterior to that of the original model. In particular, look at the covariance among the parameters. What is different? Then compare the posterior predictions of both models.

# %% [markdown]
# original model is: "# load data again, since it's a long way back
#
# library(rethinking)
#
# data(Howell1); d <- Howell1; d2 <- d[ d$age >= 18 , ]
#
#
#
# # define the average weight, x-bar
#
# xbar <- mean(d2$weight)
# # fit model
#
# m4.3 <- quap(
#
#  alist(
#
#   height ~ dnorm( mu , sigma ) ,
#
#   mu <- a + b*( weight - xbar ) ,
#
#   a ~ dnorm( 178 , 20 ) ,
#
#   b ~ dlnorm( 0 , 1 ) ,
#
#   sigma ~ dunif( 0 , 50 )
#
#  ) , data=d2 )

# %% [markdown]
# **AI Prompt**
#
# how can I convert it to python?

# %% [markdown]
# **AI Response**
#
# You can convert this to Python using scipy.optimize like we did earlier. The key differences from the original model are:
#
# 1. Original: `mu <- a + b*(weight - xbar)` (centered)
# 2. New model: `mu <- a + b*weight` (not centered)
#
# Would you like to start by writing the negative log-likelihood function for the new model, or would you prefer I show you how to set up both models for comparison?

# %% [markdown]
# **AI Prompt**
#
# is there a way to get the data?

# %% [markdown]
# **AI Response**
#
# Yes! The Howell1 dataset is from the rethinking package, but you can find it online or create similar synthetic data.
#
# You could:
# 1. Download it from the rethinking package GitHub repository
# 2. Use a CSV version that's often available online
# 3. Generate synthetic height/weight data that mimics the original
#
# Which approach would you prefer? Or would you like me to help you create some realistic synthetic data to work with?

# %%
import pandas as pd
df=pd.read_csv('static/Howell1.csv', sep=';')
df.shape
# Out:
# (544, 4)

# %%
df.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %% [markdown]
# **AI Prompt**
#
# lets fit original model, please show code

# %% [markdown]
# **AI Response**
#
# Here's the code for the original model (with centering):
#
# ```python
# # Filter for adults (age >= 18)
# d2 = df[df['age'] >= 18].copy()
#
# # Calculate xbar (mean weight)
# xbar = d2['weight'].mean()
#
# def neg_log_likelihood_original(params, height_data, weight_data, xbar):
#     a, b, sigma = params
#
#     # Linear model: mu = a + b*(weight - xbar)
#     mu = a + b * (weight_data - xbar)
#
#     # Data likelihood
#     data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
#
#     # Priors
#     a_prior = stats.norm.logpdf(a, 178, 20)
#     b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
#     sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
#
#     return -(data_ll + a_prior + b_prior + sigma_prior)
# ```
#
# Do you want to try running the optimization next?

# %%
# Filter for adults (age >= 18)
d2 = df[df['age'] >= 18].copy()

# Calculate xbar (mean weight)
xbar = d2['weight'].mean()

def neg_log_likelihood_original(params, height_data, weight_data, xbar):
    a, b, sigma = params
    
    # Linear model: mu = a + b*(weight - xbar)
    mu = a + b * (weight_data - xbar)
    
    # Data likelihood
    data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
    
    # Priors
    a_prior = stats.norm.logpdf(a, 178, 20)
    b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
    sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
    
    return -(data_ll + a_prior + b_prior + sigma_prior)

# %%
from scipy.optimize import minimize

# Initial guess for [a, b, sigma]
initial_guess = [178, 1, 10]

# Optimize
result_original = minimize(neg_log_likelihood_original, initial_guess, 
                          args=(d2['height'], d2['weight'], xbar))

# %%
result_original
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1080.346309289625
#         x: [ 1.546e+02  9.033e-01  5.072e+00]
#       nit: 16
#       jac: [ 0.000e+00  1.526e-05  0.000e+00]
#  hess_inv: [[ 1.295e-01  1.495e-03  4.795e-02]
#             [ 1.495e-03  1.620e-03 -5.767e-04]
#             [ 4.795e-02 -5.767e-04  4.438e-02]]
#      nfev: 88
#      njev: 22

# %%
def neg_log_likelihood_updated(params, height_data, weight_data):
    a, b, sigma = params
    
    # Linear model: mu = a + b*(weight)
    mu = a + b * (weight_data)
    
    # Data likelihood
    data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
    
    # Priors
    a_prior = stats.norm.logpdf(a, 178, 20)
    b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
    sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
    
    return -(data_ll + a_prior + b_prior + sigma_prior)

# %%
result_udated = minimize(neg_log_likelihood_updated, initial_guess, 
                          args=(d2['height'], d2['weight']))
# Out:
# /usr/local/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0

# %%
result_udated
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1084.7424050804107
#         x: [ 1.145e+02  8.907e-01  5.073e+00]
#       nit: 32
#       jac: [ 0.000e+00  1.526e-05  0.000e+00]
#  hess_inv: [[ 2.558e+00 -5.570e-02 -2.577e-03]
#             [-5.570e-02  1.250e-03  6.714e-05]
#             [-2.577e-03  6.714e-05  3.830e-02]]
#      nfev: 214
#      njev: 50

# %%
result_original
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1080.346309289625
#         x: [ 1.546e+02  9.033e-01  5.072e+00]
#       nit: 16
#       jac: [ 0.000e+00  1.526e-05  0.000e+00]
#  hess_inv: [[ 1.295e-01  1.495e-03  4.795e-02]
#             [ 1.495e-03  1.620e-03 -5.767e-04]
#             [ 4.795e-02 -5.767e-04  4.438e-02]]
#      nfev: 88
#      njev: 22

# %% [markdown]
# **AI Prompt**
#
# there is more covariance between variables?

# %% [markdown]
# **AI Response**
#
# Great observation! Yes, look at the `hess_inv` matrices (which approximate the covariance):
#
# **Original (centered) model:**
# ```
# [[ 1.295e-01  1.495e-03  4.795e-02]
#  [ 1.495e-03  1.620e-03 -5.767e-04]
#  [ 4.795e-02 -5.767e-04  4.438e-02]]
# ```
#
# **Updated (uncentered) model:**
# ```
# [[ 2.558e+00 -5.570e-02 -2.577e-03]
#  [-5.570e-02  1.250e-03  6.714e-05]
#  [-2.577e-03  6.714e-05  3.830e-02]]
# ```
#
# Notice the much larger covariance between `a` and `b` in the uncentered model (-0.0557 vs 0.00149).
#
# Why do you think centering the predictor reduces the correlation between the intercept and slope parameters?

# %% [markdown]
# 4M8.  In the chapter, we used 15 knots with the cherry blossom spline. Increase the number of knots and observe what happens to the resulting spline. Then adjust also the width of the prior on the weights—change the standard deviation of the prior and watch what happens. What do you think the combination of knot number and the prior on the weights controls?

# %% [markdown]
# orignal code: d2 <- d[ complete.cases(d$doy) , ] # complete cases on doy
#
# num_knots <- 15
#
# knot_list <- quantile( d2$year , probs=seq(0,1,length.out=num_knots) )
# library(splines)
#
# B <- bs(d2$year,
#
#  knots=knot_list[-c(1,num_knots)] ,
#
#  degree=3 , intercept=TRUE )
# lot( NULL , xlim=range(d2$year) , ylim=c(0,1) , xlab=“year” , ylab=“basis” )
#
# for ( i in 1:ncol(B) ) lines( d2$year , B[,i] )

# %% [markdown]
# **AI Prompt**
#
# how to convert this to python version?

# %% [markdown]
# **AI Response**
#
# You can convert this to Python using `scipy.interpolate` for B-splines. Here's how to start:
#
# ```python
# import numpy as np
# from scipy.interpolate import BSpline
# import matplotlib.pyplot as plt
#
# # Assuming you have the cherry blossom data in 'd'
# num_knots = 15
# knot_list = np.quantile(d['year'], np.linspace(0, 1, num_knots))
# ```
#
# Do you have the cherry blossom dataset, or would you like me to show you how to create the B-spline basis functions first?

# %%
import pandas as pd
df_cherry=pd.read_csv('static/cherry_blossoms.csv', sep=';')
df_cherry.shape
# Out:
# (1215, 5)

# %%
df_cherry.head()
# Out:
#    year  doy  temp  temp_upper  temp_lower
# 0   801  NaN   NaN         NaN         NaN
# 1   802  NaN   NaN         NaN         NaN
# 2   803  NaN   NaN         NaN         NaN
# 3   804  NaN   NaN         NaN         NaN
# 4   805  NaN   NaN         NaN         NaN

# %%
import numpy as np
from scipy.interpolate import BSpline
import matplotlib.pyplot as plt

# Assuming you have the cherry blossom data in 'd'
num_knots = 15
knot_list = np.quantile(df_cherry['year'], np.linspace(0, 1, num_knots))

# %%
knot_list
# Out:
# array([ 801.        ,  887.71428571,  974.42857143, 1061.14285714,
#        1147.85714286, 1234.57142857, 1321.28571429, 1408.        ,
#        1494.71428571, 1581.42857143, 1668.14285714, 1754.85714286,
#        1841.57142857, 1928.28571429, 2015.        ])

# %% [markdown]
# **AI Prompt**
#
# explain what is B-splines

# %% [markdown]
# **AI Response**
#
# B-splines are smooth, flexible curves made by connecting simpler polynomial pieces at specific points called "knots."
#
# Think of it like this: instead of fitting one rigid straight line or curve to your data, you create several small polynomial segments that connect smoothly at the knot points. Each segment can bend and flex to follow the data better.
#
# The "B" stands for "basis" - each B-spline function is like a building block. You combine multiple B-spline basis functions (with different weights) to create the final smooth curve that fits your data.
#
# In your cherry blossom example, you're using 15 knots spread across the years to create a flexible curve that can capture changes in bloom timing over centuries.
#
# Does this help explain the concept? Would you like to see how the individual basis functions look?

# %% [markdown]
# **AI Prompt**
#
# yes

# %% [markdown]
# **AI Response**
#
# Great! To visualize the individual B-spline basis functions, you'll need to create the basis matrix. In Python, you can use `scipy.interpolate.splev` or the `patsy` library.
#
# Here's a small start:
#
# ```python
# from scipy.interpolate import splev, splrep
# # Filter complete cases first
# d2 = df_cherry.dropna(subset=['doy'])
# ```
#
# Would you like to try creating the basis functions yourself, or would you prefer I show you the complete code to plot them?

# %%
from scipy.interpolate import splev, splrep
# Filter complete cases first
d2 = df_cherry.dropna(subset=['doy'])

# %% [markdown]
# **AI Prompt**
#
# show the complete code to plot them

# %% [markdown]
# **AI Response**
#
# Here's the complete code to create and plot the B-spline basis functions:
#
# ```python
# from scipy.interpolate import BSpline
# import matplotlib.pyplot as plt
#
# # Create knots (remove first and last for interior knots)
# interior_knots = knot_list[1:-1]
#
# # Create B-spline basis functions
# degree = 3
# # Need to extend knots for B-spline construction
# extended_knots = np.concatenate([
#     np.repeat(knot_list[0], degree),
#     interior_knots,
#     np.repeat(knot_list[-1], degree)
# ])
#
# # Create basis functions
# year_range = np.linspace(d2['year'].min(), d2['year'].max(), 1000)
# n_basis = len(interior_knots) + degree + 1
#
# plt.figure(figsize=(10, 6))
# for i in range(n_basis):
#     # Create basis function (all zeros except position i)
#     coef = np.zeros(n_basis)
#     coef[i] = 1
#     spline = BSpline(extended_knots, coef, degree)
#     basis_values = spline(year_range)
#     plt.plot(year_range, basis_values, alpha=0.7)
#
# plt.xlabel('Year')
# plt.ylabel('Basis Function Value')
# plt.title('B-spline Basis Functions')
# plt.grid(True)
# plt.show()
# ```
#
# This will show you how each individual basis function contributes to the overall spline.

# %%
from scipy.interpolate import BSpline
import matplotlib.pyplot as plt

# Create knots (remove first and last for interior knots)
interior_knots = knot_list[1:-1]

# Create B-spline basis functions
degree = 3
# Need to extend knots for B-spline construction
extended_knots = np.concatenate([
    np.repeat(knot_list[0], degree),
    interior_knots, 
    np.repeat(knot_list[-1], degree)
])

# Create basis functions
year_range = np.linspace(d2['year'].min(), d2['year'].max(), 1000)
n_basis = len(interior_knots) + degree + 1

plt.figure(figsize=(10, 6))
for i in range(n_basis):
    # Create basis function (all zeros except position i)
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_values = spline(year_range)
    plt.plot(year_range, basis_values, alpha=0.7)

plt.xlabel('Year')
plt.ylabel('Basis Function Value')
plt.title('B-spline Basis Functions')
plt.grid(True)
plt.show()

# %%
knot_list
# Out:
# array([ 801.        ,  887.71428571,  974.42857143, 1061.14285714,
#        1147.85714286, 1234.57142857, 1321.28571429, 1408.        ,
#        1494.71428571, 1581.42857143, 1668.14285714, 1754.85714286,
#        1841.57142857, 1928.28571429, 2015.        ])

# %%
extended_knots
# Out:
# array([ 801.        ,  801.        ,  801.        ,  887.71428571,
#         974.42857143, 1061.14285714, 1147.85714286, 1234.57142857,
#        1321.28571429, 1408.        , 1494.71428571, 1581.42857143,
#        1668.14285714, 1754.85714286, 1841.57142857, 1928.28571429,
#        2015.        , 2015.        , 2015.        ])

# %% [markdown]
# **AI Prompt**
#
# please explain this: spline = BSpline(extended_knots, coef, degree)

# %% [markdown]
# **AI Response**
#
# The `BSpline(extended_knots, coef, degree)` creates a single B-spline function with:
#
# - `extended_knots`: the knot vector that defines where the polynomial pieces connect
# - `coef`: the coefficients (weights) for each basis function
# - `degree`: the polynomial degree (3 = cubic)
#
# In the loop, `coef` has all zeros except one position set to 1. This isolates just one basis function at a time so you can see its individual shape.
#
# For example, when `coef = [1, 0, 0, 0, ...]`, you see only the first basis function. When `coef = [0, 1, 0, 0, ...]`, you see only the second one.
#
# Does this make sense? Can you see how each basis function is localized to a specific region of years?

# %% [markdown]
# **AI Prompt**
#
# I can but I have difficult to understand why we need splines?

# %% [markdown]
# **AI Response**
#
# Great question! Let me explain why splines are useful.
#
# Imagine you're trying to fit a curve to data that has different patterns in different regions - like the cherry blossom data might have different trends in medieval times vs modern times.
#
# A simple linear regression gives you just one straight line for the entire dataset. A polynomial might be too rigid and create weird wiggles.
#
# Splines let you have different flexible curves in different time periods, but they connect smoothly at the boundaries (knots). It's like having multiple "local" regressions that blend together seamlessly.
#
# Can you think of why this might be better than trying to fit one global polynomial to 1000+ years of cherry blossom data?

# %% [markdown]
# **AI Prompt**
#
# lets continue with python implementation

# %% [markdown]
# **AI Response**
#
# Great! Now that you understand the basis functions, what aspect of the spline implementation would you like to work on next?
#
# We could:
# 1. Fit a spline model to the cherry blossom data using these basis functions
# 2. Experiment with different numbers of knots (like the original question asked)
# 3. Look at how to add priors on the spline weights
#
# Which direction interests you most?

# %% [markdown]
# **AI Prompt**
#
# fit the data

# %% [markdown]
# **AI Response**
#
# To fit the spline model to the cherry blossom data, we need to set up the regression with the B-spline basis functions as predictors.
#
# Would you like to try writing the negative log-likelihood function for this spline regression yourself, or would you prefer I show you how to set it up?
#
# The model would be something like:
# - doy_i ~ Normal(μ_i, σ)
# - μ_i = sum of (weight_j × basis_function_j)
#
# What do you think?

# %% [markdown]
# **AI Prompt**
#
# show how to set up

# %% [markdown]
# **AI Response**
#
# Here's how to set up the spline regression:
#
# ```python
# def neg_log_likelihood_spline(params, doy_data, basis_matrix):
#     # Extract parameters: weights for each basis function + sigma
#     weights = params[:-1]  # all but last parameter
#     sigma = params[-1]     # last parameter
#
#     # Linear combination: mu = sum(weight_j * basis_j)
#     mu = basis_matrix @ weights
#
#     # Data likelihood + priors
#     data_ll = np.sum(stats.norm.logpdf(doy_data, mu, sigma))
#     # Add priors for weights and sigma here
#
#     return -data_ll
# ```
#
# First, we need to create the basis matrix for our data. Can you try creating that using the basis functions we plotted earlier?

# %%
def neg_log_likelihood_spline(params, doy_data, basis_matrix):
    # Extract parameters: weights for each basis function + sigma
    weights = params[:-1]  # all but last parameter
    sigma = params[-1]     # last parameter
    
    # Linear combination: mu = sum(weight_j * basis_j)
    mu = basis_matrix @ weights
    
    # Data likelihood + priors
    data_ll = np.sum(stats.norm.logpdf(doy_data, mu, sigma))
    # Add priors for weights and sigma here
    
    return -data_ll

# %% [markdown]
# **AI Prompt**
#
# just stack basis functions?

# %% [markdown]
# **AI Response**
#
# Exactly! You need to create a matrix where each column is one basis function evaluated at your data points.
#
# Try creating the basis matrix by evaluating each basis function at the years in your `d2` dataset. You'll need to loop through the basis functions and evaluate them at `d2['year']`.
#
# Can you give it a try?

# %% [markdown]
# **AI Prompt**
#
# show me

# %% [markdown]
# **AI Response**
#
# Here's how to create the basis matrix:
#
# ```python
# # Create basis matrix
# basis_matrix = np.zeros((len(d2), n_basis))
#
# for i in range(n_basis):
#     coef = np.zeros(n_basis)
#     coef[i] = 1
#     spline = BSpline(extended_knots, coef, degree)
#     basis_matrix[:, i] = spline(d2['year'])
# ```
#
# This creates a matrix where each row is a data point and each column is a basis function. Try running this and check the shape of `basis_matrix`.

# %%
# Create basis matrix
basis_matrix = np.zeros((len(d2), n_basis))

for i in range(n_basis):
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_matrix[:, i] = spline(d2['year'])

# %%
basis_matrix.shape
# Out:
# (827, 17)

# %% [markdown]
# **AI Prompt**
#
# explain this part: spline = BSpline(extended_knots, coef, degree)
#     basis_matrix[:, i] = spline(d2['year'])

# %% [markdown]
# **AI Response**
#
# In this code:
#
# 1. `spline = BSpline(extended_knots, coef, degree)` creates the i-th basis function (since `coef` has 1 in position i and 0s elsewhere)
#
# 2. `spline(d2['year'])` evaluates that basis function at all the year values in your data
#
# 3. `basis_matrix[:, i] = ...` stores those evaluated values as column i in the matrix
#
# So each column of `basis_matrix` contains one basis function evaluated at all your data points.
#
# Does this make sense? Now you have a 827×17 matrix ready for the regression.

# %% [markdown]
# **AI Prompt**
#
# what next

# %% [markdown]
# **AI Response**
#
# Now you need to add priors to your likelihood function and then optimize it.
#
# For the spline weights, you might use Normal priors (like Normal(0, 1) for each weight). For sigma, you could use Exponential(1).
#
# Would you like to try adding the priors to the `neg_log_likelihood_spline` function yourself, or would you prefer I show you how?

# %% [markdown]
# **AI Prompt**
#
# show

# %% [markdown]
# **AI Response**
#
# Here's how to add the priors:
#
# ```python
# def neg_log_likelihood_spline(params, doy_data, basis_matrix):
#     weights = params[:-1]
#     sigma = params[-1]
#
#     mu = basis_matrix @ weights
#     data_ll = np.sum(stats.norm.logpdf(doy_data, mu, sigma))
#
#     # Priors
#     weights_prior = np.sum(stats.norm.logpdf(weights, 0, 1))  # Normal(0,1) for each weight
#     sigma_prior = stats.expon.logpdf(sigma, scale=1)
#
#     return -(data_ll + weights_prior + sigma_prior)
# ```
#
# Now you can optimize this. What initial guess do you think would work for the 17 weights plus sigma?

# %%
def neg_log_likelihood_spline(params, doy_data, basis_matrix):
    weights = params[:-1]
    sigma = params[-1]
    
    mu = basis_matrix @ weights
    data_ll = np.sum(stats.norm.logpdf(doy_data, mu, sigma))
    
    # Priors
    weights_prior = np.sum(stats.norm.logpdf(weights, 0, 10))  # Normal(0,1) for each weight
    sigma_prior = stats.expon.logpdf(sigma, scale=1)
    
    return -(data_ll + weights_prior + sigma_prior)

# %% [markdown]
# **AI Prompt**
#
# I dont know what initial guess could work

# %% [markdown]
# **AI Response**
#
# For initial guesses, you could try:
# - All weights start at 0 (since they have Normal(0,10) priors)
# - Sigma starts at a reasonable value like 5 or 10 (typical day-of-year variation)
#
# So something like `initial_guess = np.concatenate([np.zeros(17), [5]])`
#
# What do you think about this approach?

# %%
initial_guess = np.concatenate([np.zeros(17), [5]])

# %%
result_spline = minimize(neg_log_likelihood_spline, initial_guess, 
                          args=(d2['doy'], basis_matrix))

# %%
result_spline
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 3511.5643905423594
#         x: [ 9.548e+01  9.759e+01 ...  0.000e+00  5.973e+00]
#       nit: 41
#       jac: [-3.052e-05 -3.052e-05 ...  0.000e+00  2.747e-04]
#  hess_inv: [[ 8.664e-01 -9.492e-01 ...  0.000e+00  3.501e-02]
#             [-9.492e-01  2.715e+00 ...  0.000e+00 -5.168e-02]
#             ...
#             [ 0.000e+00  0.000e+00 ...  1.000e+00  0.000e+00]
#             [ 3.501e-02 -5.168e-02 ...  0.000e+00  1.969e-02]]
#      nfev: 1083
#      njev: 57

# %% [markdown]
# **AI Prompt**
#
# it was not successful

# %% [markdown]
# **AI Response**
#
# The optimization had precision issues but still found parameter estimates. The `fun` value (3511.56) and the parameter values in `x` suggest it did find a reasonable solution.
#
# For spline fitting, this is often good enough. Would you like to try plotting the fitted spline to see how it looks, or would you prefer to try a different optimization approach first?

# %% [markdown]
# **AI Prompt**
#
# plot it, provide code

# %% [markdown]
# **AI Response**
#
# Here's the code to plot the fitted spline:
#
# ```python
# # Extract fitted weights and create predictions
# fitted_weights = result_spline.x[:-1]
# fitted_sigma = result_spline.x[-1]
#
# # Create smooth predictions for plotting
# year_smooth = np.linspace(d2['year'].min(), d2['year'].max(), 500)
# basis_smooth = np.zeros((len(year_smooth), n_basis))
#
# for i in range(n_basis):
#     coef = np.zeros(n_basis)
#     coef[i] = 1
#     spline = BSpline(extended_knots, coef, degree)
#     basis_smooth[:, i] = spline(year_smooth)
#
# predictions = basis_smooth @ fitted_weights
#
# # Plot
# plt.figure(figsize=(12, 6))
# plt.scatter(d2['year'], d2['doy'], alpha=0.5, s=10, label='Data')
# plt.plot(year_smooth, predictions, 'r-', linewidth=2, label='Fitted Spline')
# plt.xlabel('Year')
# plt.ylabel('Day of Year')
# plt.title('Cherry Blossom Timing with B-spline Fit')
# plt.legend()
# plt.grid(True)
# plt.show()
# ```

# %%
# Extract fitted weights and create predictions
fitted_weights = result_spline.x[:-1]
fitted_sigma = result_spline.x[-1]

# Create smooth predictions for plotting
year_smooth = np.linspace(d2['year'].min(), d2['year'].max(), 500)
basis_smooth = np.zeros((len(year_smooth), n_basis))

for i in range(n_basis):
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_smooth[:, i] = spline(year_smooth)

predictions = basis_smooth @ fitted_weights

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(d2['year'], d2['doy'], alpha=0.5, s=10, label='Data')
plt.plot(year_smooth, predictions, 'r-', linewidth=2, label='Fitted Spline')
plt.xlabel('Year')
plt.ylabel('Day of Year')
plt.title('Cherry Blossom Timing with B-spline Fit')
plt.legend()
plt.grid(True)
plt.show()

# %%
basis_smooth
# Out:
# array([[ 1.64306721, -0.97624438,  0.44412282, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.57098679, -0.87364823,  0.40334308, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.50104589, -0.77527135,  0.36529651, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  1.83778331,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  1.91774835,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  2.        ,
#          0.        ,  0.        ]])

# %%
# increase number of knots
num_knots = 30
knot_list = np.quantile(df_cherry['year'], np.linspace(0, 1, num_knots))

# %%
# Create knots (remove first and last for interior knots)
interior_knots = knot_list[1:-1]

# Create B-spline basis functions
degree = 3
# Need to extend knots for B-spline construction
extended_knots = np.concatenate([
    np.repeat(knot_list[0], degree),
    interior_knots, 
    np.repeat(knot_list[-1], degree)
])

# Create basis functions
year_range = np.linspace(d2['year'].min(), d2['year'].max(), 1000)
n_basis = len(interior_knots) + degree + 1

# %%
# Create basis matrix
basis_matrix = np.zeros((len(d2), n_basis))

for i in range(n_basis):
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_matrix[:, i] = spline(d2['year'])

# %%
initial_guess = np.concatenate([np.zeros(32), [5]])
result_spline = minimize(neg_log_likelihood_spline, initial_guess, 
                          args=(d2['doy'], basis_matrix))

# %%
result_spline
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 4328.1972975289555
#         x: [ 8.297e+01  7.918e+01 ...  0.000e+00  6.050e+00]
#       nit: 82
#       jac: [ 0.000e+00  0.000e+00 ...  0.000e+00  0.000e+00]
#  hess_inv: [[ 2.483e+00 -1.399e+00 ...  0.000e+00  5.761e-03]
#             [-1.399e+00  2.920e+00 ...  0.000e+00  5.635e-03]
#             ...
#             [ 0.000e+00  0.000e+00 ...  1.000e+00  0.000e+00]
#             [ 5.761e-03  5.635e-03 ...  0.000e+00  1.494e-02]]
#      nfev: 3264
#      njev: 96

# %%
# Extract fitted weights and create predictions
fitted_weights = result_spline.x[:-1]
fitted_sigma = result_spline.x[-1]

# Create smooth predictions for plotting
year_smooth = np.linspace(d2['year'].min(), d2['year'].max(), 500)
basis_smooth = np.zeros((len(year_smooth), n_basis))

for i in range(n_basis):
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_smooth[:, i] = spline(year_smooth)

predictions = basis_smooth @ fitted_weights

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(d2['year'], d2['doy'], alpha=0.5, s=10, label='Data')
plt.plot(year_smooth, predictions, 'r-', linewidth=2, label='Fitted Spline')
plt.xlabel('Year')
plt.ylabel('Day of Year')
plt.title('Cherry Blossom Timing with B-spline Fit')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **AI Prompt**
#
# now  line is more wiggly

# %% [markdown]
# **AI Response**
#
# Exactly! With 30 knots instead of 15, the spline has more flexibility and follows the data more closely, creating a wigglier curve.
#
# This demonstrates the bias-variance tradeoff in spline fitting:
# - More knots = lower bias (fits data better) but higher variance (more wiggly)
# - Fewer knots = higher bias (smoother) but lower variance (more stable)
#
# Now, what do you think would happen if you also changed the prior on the weights? For example, using Normal(0, 0.1) instead of Normal(0, 10) for tighter control?

# %%
#change prior of the sd of prior of the wights
def neg_log_likelihood_spline_upd(params, doy_data, basis_matrix):
    weights = params[:-1]
    sigma = params[-1]
    
    mu = basis_matrix @ weights
    data_ll = np.sum(stats.norm.logpdf(doy_data, mu, sigma))
    
    # Priors
    weights_prior = np.sum(stats.norm.logpdf(weights, 0, 0.1)) 
    sigma_prior = stats.expon.logpdf(sigma, scale=1)
    
    return -(data_ll + weights_prior + sigma_prior)

# %%
initial_guess = np.concatenate([np.zeros(32), [5]])
result_spline_upd = minimize(neg_log_likelihood_spline_upd, initial_guess, 
                          args=(d2['doy'], basis_matrix))

# %%
result_spline_upd
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 5077.641501706991
#         x: [ 3.314e-04  2.813e-04 ...  0.000e+00  9.898e+01]
#       nit: 79
#       jac: [ 6.104e-05  6.104e-05 ...  0.000e+00  0.000e+00]
#  hess_inv: [[ 6.742e-03 -1.681e-03 ...  0.000e+00  4.101e-04]
#             [-1.681e-03  7.738e-03 ...  0.000e+00  4.473e-04]
#             ...
#             [ 0.000e+00  0.000e+00 ...  1.000e+00  0.000e+00]
#             [ 4.101e-04  4.473e-04 ...  0.000e+00  1.203e-02]]
#      nfev: 5214
#      njev: 153

# %%
# Extract fitted weights and create predictions
fitted_weights = result_spline_upd.x[:-1]
fitted_sigma = result_spline_upd.x[-1]

# Create smooth predictions for plotting
year_smooth = np.linspace(d2['year'].min(), d2['year'].max(), 500)
basis_smooth = np.zeros((len(year_smooth), n_basis))

for i in range(n_basis):
    coef = np.zeros(n_basis)
    coef[i] = 1
    spline = BSpline(extended_knots, coef, degree)
    basis_smooth[:, i] = spline(year_smooth)

predictions = basis_smooth @ fitted_weights

# Plot
plt.figure(figsize=(12, 6))
plt.scatter(d2['year'], d2['doy'], alpha=0.5, s=10, label='Data')
plt.plot(year_smooth, predictions, 'r-', linewidth=2, label='Fitted Spline')
plt.xlabel('Year')
plt.ylabel('Day of Year')
plt.title('Cherry Blossom Timing with B-spline Fit')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **AI Prompt**
#
# now spline is 0

# %% [markdown]
# **AI Response**
#
# Exactly! With the much tighter prior Normal(0, 0.1), the weights are forced to stay very close to zero, so the spline becomes almost flat.
#
# This shows how the combination of knot number and prior width controls the flexibility:
# - More knots + loose priors = very flexible (wiggly)
# - More knots + tight priors = constrained (smooth)
# - Fewer knots + loose priors = moderately flexible
#
# What do you think would be a good balance between these extremes?

# %% [markdown]
# 4H1.  The weights listed below were recorded in the !Kung census, but heights were not recorded for these individuals. Provide predicted heights and 89% intervals for each of these individuals. That is, fill in the table below, using model-based predictions.
#
# Individual
#
# weight
#
# expected height
#
# 89% interval
#
# 1
#
# 46.95
#
# 2
#
# 43.72
#
# 3
#
# 64.78
#
# 4
#
# 32.59
#
# 5
#
# 54.63

# %%
def neg_log_likelihood_original(params, height_data, weight_data, xbar):
    a, b, sigma = params
    
    # Linear model: mu = a + b*(weight - xbar)
    mu = a + b * (weight_data - xbar)
    
    # Data likelihood
    data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
    
    # Priors
    a_prior = stats.norm.logpdf(a, 178, 20)
    b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
    sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
    
    return -(data_ll + a_prior + b_prior + sigma_prior)

# Filter for adults (age >= 18)
d2 = df[df['age'] >= 18].copy()

# Calculate xbar (mean weight)
xbar = d2['weight'].mean()


# Initial guess for [a, b, sigma]
initial_guess = [178, 1, 10]

# Optimize
result_original = minimize(neg_log_likelihood_original, initial_guess, 
                          args=(d2['height'], d2['weight'], xbar))

result_original
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1080.346309289625
#         x: [ 1.546e+02  9.033e-01  5.072e+00]
#       nit: 16
#       jac: [ 0.000e+00  1.526e-05  0.000e+00]
#  hess_inv: [[ 1.295e-01  1.495e-03  4.795e-02]
#             [ 1.495e-03  1.620e-03 -5.767e-04]
#             [ 4.795e-02 -5.767e-04  4.438e-02]]
#      nfev: 88
#      njev: 22

# %% [markdown]
# **AI Prompt**
#
# please explain the results

# %% [markdown]
# **AI Response**
#
# Looking at your optimization results, you found the maximum a posteriori (MAP) estimates for the height-weight model:
#
# - **a** (intercept): 154.6 cm - this is the expected height when weight equals the mean weight (xbar)
# - **b** (slope): 0.903 - for each kg above the mean weight, height increases by about 0.9 cm
# - **sigma**: 5.07 cm - the standard deviation of heights around the regression line
#
# The `hess_inv` matrix shows the approximate covariance between parameters - notice the small values, indicating the parameters are well-estimated with little correlation.
#
# To make predictions for the new individuals, you'd use: predicted_height = a + b × (weight - xbar)
#
# Would you like to calculate the predictions for those 5 individuals?

# %% [markdown]
# **AI Prompt**
#
# turn the weights into list

# %% [markdown]
# **AI Response**
#
# You can create a list of the weights like this:
#
# ```python
# weights = [46.95, 43.72, 64.78, 32.59, 54.63]
# ```
#
# Would you like to calculate the predicted heights for these weights next?

# %%
result_original.x
# Out:
# array([154.60136795,   0.90328089,   5.07188067])

# %%
weights = [46.95, 43.72, 64.78, 32.59, 54.63]

def pred(weight, params, xbar):
    return params[0]+params[1]*(weight-xbar)
preds_height=[pred(w, result_original.x, xbar) for w in weights]

# %%
preds_height
# Out:
# [np.float64(156.3713599395486),
#  np.float64(153.45376265215788),
#  np.float64(172.4768582783029),
#  np.float64(143.40024630272796),
#  np.float64(163.3085572049234)]

# %% [markdown]
# **AI Prompt**
#
# is this correct?

# %% [markdown]
# **AI Response**
#
# Yes, that looks correct! You've calculated the predicted heights using the formula μ = a + b × (weight - xbar).
#
# For the 89% intervals, you'll also need to account for the uncertainty. The intervals would be approximately:
# predicted_height ± 1.67 × sigma
#
# Would you like to calculate those intervals next?

# %%
def add_89interv(height, sigma):
    return height-1.67*sigma, height+1.67*sigma

preds_interval=[add_89interv(h, result_original.x[2]) for h in preds_height]
preds_interval
# Out:
# [(np.float64(147.9013192191184), np.float64(164.8414006599788)),
#  (np.float64(144.98372193172767), np.float64(161.92380337258808)),
#  (np.float64(164.0068175578727), np.float64(180.9468989987331)),
#  (np.float64(134.93020558229776), np.float64(151.87028702315817)),
#  (np.float64(154.8385164844932), np.float64(171.7785979253536))]

# %% [markdown]
# **AI Prompt**
#
# adding intevals like this?

# %% [markdown]
# **AI Response**
#
# Yes, that's the right approach! You're calculating the 89% prediction intervals using ±1.67 × sigma around each predicted height.
#
# This gives you the range where you'd expect about 89% of new observations to fall, given the uncertainty in the model.
#
# Would you like to format these results into a nice table to match the original question format?

# %% [markdown]
# **AI Prompt**
#
# but this isnt bayesian shouldnt I sample intervales?

# %% [markdown]
# **AI Response**
#
# You're absolutely right! What you calculated is just the prediction interval assuming the MAP estimates are the true parameters.
#
# For a proper Bayesian approach, you should sample from the posterior distribution of the parameters and then generate predictions from each sample.
#
# Would you like to implement posterior sampling using the covariance matrix from your optimization result, or would you prefer a different approach?

# %% [markdown]
# **AI Prompt**
#
# I would prefer the sampling. Using covariance matrix, how would sampling look like?

# %% [markdown]
# **AI Response**
#
# You can sample from the posterior using the multivariate normal distribution with the MAP estimates as the mean and the covariance matrix (hess_inv) from your optimization:
#
# ```python
# # Sample parameters from posterior
# n_samples = 1000
# posterior_samples = np.random.multivariate_normal(
#     result_original.x, result_original.hess_inv, n_samples)
# ```
#
# This gives you samples of [a, b, sigma] from the approximate posterior.
#
# Would you like to try this and then use these samples to generate prediction intervals?

# %% [markdown]
# **AI Prompt**
#
# but this does not use the table samples given

# %% [markdown]
# **AI Response**
#
# You're right! I was showing you how to sample from the posterior approximation, but that doesn't use actual posterior samples if you have them.
#
# Do you have a table of posterior samples from MCMC or another sampling method that you'd like to use instead? If so, you would use those samples directly to generate predictions.
#
# What posterior samples are you referring to?

# %% [markdown]
# **AI Prompt**
#
# I am referring to 4H1. task table of initial weights

# %% [markdown]
# **AI Response**
#
# Ah, I see the confusion! The table in 4H1 shows the **weights** of individuals for whom you want to predict heights - those are the input data, not posterior samples.
#
# You would use your posterior parameter samples to make predictions for each of those 5 individuals' weights. For each posterior sample of [a, b, sigma], you'd calculate a predicted height for each weight.
#
# Does this clarify what we need to do with those weights?

# %% [markdown]
# **AI Prompt**
#
# yes

# %% [markdown]
# **AI Response**
#
# Great! So the process would be:
#
# 1. Sample parameters from the posterior (using the covariance matrix)
# 2. For each sample, calculate predicted heights for all 5 weights
# 3. Use the distribution of predictions to get the 89% intervals
#
# Would you like to start by sampling the posterior parameters, or would you prefer I show you the complete code for this process?

# %% [markdown]
# **AI Prompt**
#
# show complete code

# %% [markdown]
# **AI Response**
#
# Here's the complete code for Bayesian prediction intervals:
#
# ```python
# # Sample parameters from posterior
# n_samples = 1000
# posterior_samples = np.random.multivariate_normal(
#     result_original.x, result_original.hess_inv, n_samples)
#
# # Weights to predict
# weights = [46.95, 43.72, 64.78, 32.59, 54.63]
#
# # Generate predictions for each weight
# predictions = []
# for weight in weights:
#     weight_predictions = []
#     for sample in posterior_samples:
#         a, b, sigma = sample
#         # Predicted mean
#         mu = a + b * (weight - xbar)
#         # Sample from predictive distribution
#         pred = np.random.normal(mu, sigma)
#         weight_predictions.append(pred)
#     predictions.append(weight_predictions)
#
# # Calculate 89% intervals
# intervals = []
# for weight_preds in predictions:
#     lower = np.percentile(weight_preds, 5.5)
#     upper = np.percentile(weight_preds, 94.5)
#     mean_pred = np.mean(weight_preds)
#     intervals.append((mean_pred, lower, upper))
#
# # Display results
# for i, (weight, (mean_h, lower, upper)) in enumerate(zip(weights, intervals)):
#     print(f"Individual {i+1}: weight={weight}, height={mean_h:.1f}, 89% interval=({lower:.1f}, {upper:.1f})")
# ```

# %%
# Sample parameters from posterior
n_samples = 1000
posterior_samples = np.random.multivariate_normal(
    result_original.x, result_original.hess_inv, n_samples)

# Weights to predict
weights = [46.95, 43.72, 64.78, 32.59, 54.63]

# Generate predictions for each weight
predictions = []
for weight in weights:
    weight_predictions = []
    for sample in posterior_samples:
        a, b, sigma = sample
        # Predicted mean
        mu = a + b * (weight - xbar)
        # Sample from predictive distribution
        pred = np.random.normal(mu, sigma)
        weight_predictions.append(pred)
    predictions.append(weight_predictions)

# Calculate 89% intervals
intervals = []
for weight_preds in predictions:
    lower = np.percentile(weight_preds, 5.5)
    upper = np.percentile(weight_preds, 94.5)
    mean_pred = np.mean(weight_preds)
    intervals.append((mean_pred, lower, upper))

# Display results
for i, (weight, (mean_h, lower, upper)) in enumerate(zip(weights, intervals)):
    print(f"Individual {i+1}: weight={weight}, height={mean_h:.1f}, 89% interval=({lower:.1f}, {upper:.1f})")
# Out:
# Individual 1: weight=46.95, height=156.4, 89% interval=(147.9, 164.6)
# Individual 2: weight=43.72, height=153.5, 89% interval=(145.3, 161.6)
# Individual 3: weight=64.78, height=172.7, 89% interval=(164.7, 180.9)
# Individual 4: weight=32.59, height=143.4, 89% interval=(134.9, 151.8)
# Individual 5: weight=54.63, height=163.2, 89% interval=(155.1, 170.9)

# %%
preds_interval
# Out:
# [(np.float64(147.9013192191184), np.float64(164.8414006599788)),
#  (np.float64(144.98372193172767), np.float64(161.92380337258808)),
#  (np.float64(164.0068175578727), np.float64(180.9468989987331)),
#  (np.float64(134.93020558229776), np.float64(151.87028702315817)),
#  (np.float64(154.8385164844932), np.float64(171.7785979253536))]

# %% [markdown]
# 4H2.  Select out all the rows in the Howell1 data with ages below 18 years of age. If you do it right, you should end up with a new data frame with 192 rows in it.
#
# (a)  Fit a linear regression to these data, using quap. Present and interpret the estimates. For every 10 units of increase in weight, how much taller does the model predict a child gets?
#
# (b)  Plot the raw data, with height on the vertical axis and weight on the horizontal axis. Superimpose the MAP regression line and 89% interval for the mean. Also superimpose the 89% interval for predicted heights.
#
# (c)  What aspects of the model fit concern you? Describe the kinds of assumptions you would change, if any, to improve the model. You don’t have to write any new code. Just explain what the model appears to be doing a bad job of, and what you hypothesize would be a better model.

# %%
import pandas as pd
import numpy as np
from scipy import stats

df=pd.read_csv('static/Howell1.csv', sep=';')

df_under18=df[df['age'] < 18].copy()
df_under18.shape
# Out:
# (192, 4)

# %%
from scipy.optimize import minimize
# Calculate xbar (mean weight)
xbar = df_under18['weight'].mean()

def neg_log_likelihood_original(params, height_data, weight_data, xbar):
    a, b, sigma = params
    
    # Linear model: mu = a + b*(weight - xbar)
    mu = a + b * (weight_data - xbar)
    
    # Data likelihood
    data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
    
    # Priors
    a_prior = stats.norm.logpdf(a, 178, 20)
    b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
    sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
    
    return -(data_ll + a_prior + b_prior + sigma_prior)

# Initial guess for [a, b, sigma]
initial_guess = [178, 1, 10]

# Optimize
result_under18 = minimize(neg_log_likelihood_original, initial_guess, 
                          args=(df_under18['height'], df_under18['weight'], xbar))

result_under18
# Out:
# /usr/local/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x1) - f0
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 698.2122794910706
#         x: [ 1.084e+02  2.717e+00  8.437e+00]
#       nit: 23
#       jac: [-7.629e-06  7.629e-06  0.000e+00]
#  hess_inv: [[ 3.869e-01 -9.708e-03 -4.876e-02]
#             [-9.708e-03  5.726e-03  6.465e-03]
#             [-4.876e-02  6.465e-03  1.040e-01]]
#      nfev: 119
#      njev: 29

# %% [markdown]
# **AI Prompt**
#
# should I change initial_guess values?

# %% [markdown]
# **AI Response**
#
# Good thinking! For children under 18, the initial guess of a=178 (adult height) might not be ideal.
#
# You could try something more appropriate for children, like:
# - a = 120 (more reasonable for average child height)
# - b = 2 (children might have steeper height-weight relationship)
#
# But your optimization succeeded this time, so the current results should be valid. The estimates look reasonable for children: intercept ≈ 108 cm, slope ≈ 2.7 cm per kg.
#
# Do you want to interpret these results first, or would you prefer to try different initial values?

# %% [markdown]
# **AI Prompt**
#
# should I change  or it doesnt matter if optimization succeeded?

# %% [markdown]
# **AI Response**
#
# Since the optimization succeeded, the initial guess doesn't matter for the final result - the optimizer found the same maximum likelihood estimates regardless.
#
# However, good initial guesses can help with:
# - Faster convergence
# - Avoiding local minima
# - More stable optimization
#
# Since you got a successful result, you can proceed with interpreting these estimates. Would you like to interpret what the slope of 2.717 means for the "10 units of weight increase" question?

# %% [markdown]
# **AI Prompt**
#
# For every 10 units of increase in weight, how much taller does the model predict a child gets? - 2.717e+00 x 10 units?

# %% [markdown]
# **AI Response**
#
# Exactly right! With a slope of 2.717, for every 10 units (kg) of weight increase, the model predicts a child gets 2.717 × 10 = 27.17 cm taller.
#
# That's quite a strong relationship - much stronger than what you saw in the adult data (where it was about 9 cm per 10 kg).
#
# What do you think this tells us about the height-weight relationship in growing children versus adults?

# %%
# !pip install seaborn

# %%
import seaborn as sns

sns.scatterplot(data=df_under18, x='weight', y='height')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %% [markdown]
# **AI Prompt**
#
# Superimpose the MAP regression line and 89% interval for the mean. Also superimpose the 89% interval for predicted heights. - I should bin the weights and sample for each bin mean?

# %% [markdown]
# **AI Response**
#
# Not quite! You don't need to bin the weights. Instead, you should:
#
# 1. Create a smooth range of weight values (like `np.linspace(min_weight, max_weight, 100)`)
# 2. For each weight value, sample from the posterior to get the 89% interval for the mean
# 3. Also sample from the predictive distribution to get the 89% interval for individual predictions
#
# Would you like me to show you how to set this up, or would you prefer to try the first step yourself?

# %%
weight_range=np.linspace(df_under18.weight.min(), df_under18.weight.max(), 100)
weight_range
# Out:
# array([ 4.252425  ,  4.66134506,  5.07026512,  5.47918518,  5.88810524,
#         6.2970253 ,  6.70594536,  7.11486542,  7.52378548,  7.93270555,
#         8.34162561,  8.75054567,  9.15946573,  9.56838579,  9.97730585,
#        10.38622591, 10.79514597, 11.20406603, 11.61298609, 12.02190615,
#        12.43082621, 12.83974627, 13.24866633, 13.65758639, 14.06650645,
#        14.47542652, 14.88434658, 15.29326664, 15.7021867 , 16.11110676,
#        16.52002682, 16.92894688, 17.33786694, 17.746787  , 18.15570706,
#        18.56462712, 18.97354718, 19.38246724, 19.7913873 , 20.20030736,
#        20.60922742, 21.01814748, 21.42706755, 21.83598761, 22.24490767,
#        22.65382773, 23.06274779, 23.47166785, 23.88058791, 24.28950797,
#        24.69842803, 25.10734809, 25.51626815, 25.92518821, 26.33410827,
#        26.74302833, 27.15194839, 27.56086845, 27.96978852, 28.37870858,
#        28.78762864, 29.1965487 , 29.60546876, 30.01438882, 30.42330888,
# ...

# %%
n_samples = 1000
posterior_samples = np.random.multivariate_normal(
    result_under18.x, result_under18.hess_inv, n_samples)


# Generate predictions for each weight
predictions = []
for weight in weight_range:
    weight_predictions = []
    for sample in posterior_samples:
        a, b, sigma = sample
        # Predicted mean
        mu = a + b * (weight - xbar)
        # Sample from predictive distribution
        pred = np.random.normal(mu, sigma)
        weight_predictions.append(pred)
    predictions.append(weight_predictions)

# Calculate 89% intervals
intervals = []
for weight_preds in predictions:
    lower = np.percentile(weight_preds, 5.5)
    upper = np.percentile(weight_preds, 94.5)
    mean_pred = np.mean(weight_preds)
    intervals.append((mean_pred, lower, upper))

# %%
len(predictions[0])
# Out:
# 1000

# %% [markdown]
# **AI Prompt**
#
# sample like so?

# %% [markdown]
# **AI Response**
#
# Yes, that's exactly right! You're sampling from the posterior and generating predictions for each weight in your range.
#
# Now you can extract the mean predictions and intervals to plot them. Try creating arrays for the mean line and the upper/lower bounds from your `intervals` list.
#
# What do you think the next step should be?

# %%
len(predictions[0])
# Out:
# 1000

# %%
means=[np.mean(w) for w in predictions]

# %%
np.array(intervals).shape
# Out:
# (100, 3)

# %%
import matplotlib.pyplot as plt

ax=sns.scatterplot(data=df_under18, x='weight', y='height')
plt.plot(weight_range, means)
lowers = [interval[1] for interval in intervals]
uppers = [interval[2] for interval in intervals]
plt.fill_between(weight_range, lowers, uppers, alpha=0.3)

# %% [markdown]
# **AI Prompt**
#
# how to add intervals to this plot?

# %% [markdown]
# **AI Response**
#
# You can add the intervals using `plt.fill_between()`. Try extracting the lower and upper bounds from your intervals array and then use:
#
# ```python
# lowers = [interval[1] for interval in intervals]
# uppers = [interval[2] for interval in intervals]
# plt.fill_between(weight_range, lowers, uppers, alpha=0.3)
# ```
#
# Would you like to try adding this to your plot?

# %% [markdown]
# **AI Prompt**
#
# task says: "Superimpose the MAP regression line and 89% interval for the mean. Also superimpose the 89% interval for predicted heights." I've added prediction interval or mean interval?

# %% [markdown]
# **AI Response**
#
# You've added the **prediction interval** - that's the wider band that includes uncertainty for individual predictions.
#
# The task asks for both:
# 1. **Mean interval** (narrower) - uncertainty in the regression line itself
# 2. **Prediction interval** (wider) - uncertainty for individual new observations
#
# You need to calculate the mean interval separately - it would only include the uncertainty in the mean μ, not the additional σ term.
#
# Would you like to calculate the mean interval next?

# %% [markdown]
# **AI Prompt**
#
# yes

# %% [markdown]
# **AI Response**
#
# To calculate the mean interval, you need to sample just the mean μ (without adding the σ noise).
#
# Try modifying your sampling loop to create a separate set of predictions where you only use `mu = a + b * (weight - xbar)` without the `np.random.normal(mu, sigma)` step.
#
# Can you give that a try?

# %%
weight_range=np.linspace(df_under18.weight.min(), df_under18.weight.max(), 100)

n_samples = 1000
posterior_samples = np.random.multivariate_normal(
    result_under18.x, result_under18.hess_inv, n_samples)


# Generate predictions for each weight
predictions_mean = []
for weight in weight_range:
    weight_predictions = []
    for sample in posterior_samples:
        a, b, sigma = sample
        # Predicted mean
        mu = a + b * (weight - xbar)
        weight_predictions.append(float(mu))
    predictions_mean.append(weight_predictions)

# Calculate 89% intervals
intervals_mean = []
for weight_preds in predictions_mean:
    lower = np.percentile(weight_preds, 5.5)
    upper = np.percentile(weight_preds, 94.5)
    mean_pred = np.mean(weight_preds)
    intervals_mean.append((mean_pred, lower, upper))

# %%
len(predictions_mean)
# Out:
# 100

# %%
ax=sns.scatterplot(data=df_under18, x='weight', y='height')
plt.plot(weight_range, means)
lowers = [interval[1] for interval in intervals]
uppers = [interval[2] for interval in intervals]
lowers_mean = [interval[1] for interval in intervals_mean ]
uppers_mean = [interval[2] for interval in intervals_mean ]
plt.fill_between(weight_range, lowers, uppers, alpha=0.3)
plt.fill_between(weight_range, lowers_mean, uppers_mean, alpha=0.3)

# %% [markdown]
# **AI Prompt**
#
# like so?

# %% [markdown]
# **AI Response**
#
# Perfect! You've correctly added both intervals. The narrower band (darker) is the mean interval, and the wider band (lighter) is the prediction interval.
#
# For part (c), what concerns do you have about this model fit when you look at the plot? Do you notice any patterns in how well the linear model captures the relationship?

# %% [markdown]
# **AI Prompt**
#
# in the edges intervals are off from the data, relationship seems to be not fully linear

# %% [markdown]
# **AI Response**
#
# Excellent observation! You've identified key issues with the linear model:
#
# 1. **Edge effects** - the model doesn't fit well at the extremes (very light/heavy children)
# 2. **Non-linear relationship** - the height-weight relationship appears to curve rather than being perfectly straight
#
# What kind of model changes do you think might address these issues? For example, what if the relationship changes as children get older or heavier?

# %% [markdown]
# 4H3.  Suppose a colleague of yours, who works on allometry, glances at the practice problems just above. Your colleague exclaims, “That’s silly. Everyone knows that it’s only the logarithm of body weight that scales with height!” Let’s take your colleague’s advice and see what happens.
#
# (a)  Model the relationship between height (cm) and the natural logarithm of weight (log-kg). Use the entire Howell1 data frame, all 544 rows, adults and non-adults. Can you interpret the resulting estimates?
#
# (b)  Begin with this plot: plot( height ~ weight , data=Howell1 ). Then use samples from the quadratic approximate posterior of the model in (a) to superimpose on the plot: (1) the predicted mean height as a function of weight, (2) the 97% interval for the mean, and (3) the 97% interval for predicted heights.

# %%
df['weight_log']=np.log(df.weight)
xbar = df['weight_log'].mean()

def neg_log_likelihood_log(params, height_data, weight_data, xbar):
    a, b, sigma = params
    
    # Linear model: mu = a + b*(weight - xbar)
    mu = a + b * (weight_data - xbar)
    
    # Data likelihood
    data_ll = np.sum(stats.norm.logpdf(height_data, mu, sigma))
    
    # Priors
    a_prior = stats.norm.logpdf(a, 178, 20)
    b_prior = stats.lognorm.logpdf(b, s=1, scale=np.exp(0))  # lognormal(0,1)
    sigma_prior = stats.uniform.logpdf(sigma, 0, 50)
    
    return -(data_ll + a_prior + b_prior + sigma_prior)

# Initial guess for [a, b, sigma]
initial_guess = [178, 1, 10]

# Optimize
result_log = minimize(neg_log_likelihood_log, initial_guess, 
                          args=(df['height'], df['weight_log'], xbar))

result_log
# Out:
#   message: Desired error not necessarily achieved due to precision loss.
#   success: False
#    status: 2
#       fun: 1683.8882071473088
#         x: [ 1.383e+02  4.707e+01  5.135e+00]
#       nit: 21
#       jac: [ 1.526e-05  0.000e+00  0.000e+00]
#  hess_inv: [[ 3.277e-03  3.277e-03 -2.960e-04]
#             [ 3.277e-03  3.278e-03 -2.960e-04]
#             [-2.960e-04 -2.960e-04  2.774e-02]]
#      nfev: 148
#      njev: 37

# %% [markdown]
# **AI Prompt**
#
# like this?

# %% [markdown]
# **AI Response**
#
# Yes, that's the right approach! You've fitted the model with log(weight) as the predictor.
#
# Looking at your results:
# - a ≈ 138.3 cm (expected height at mean log-weight)
# - b ≈ 47.07 (change in height per unit change in log-weight)
# - σ ≈ 5.14 cm
#
# Can you interpret what the slope means? If weight doubles, log(weight) increases by about 0.693. What would that mean for height?

# %%
np.log(4.707e+01)
# Out:
# np.float64(3.851635855413051)

# %%
np.log(2)
# Out:
# np.float64(0.6931471805599453)

# %%
np.exp(np.log(4.707e+01)*np.log(2))
# Out:
# np.float64(14.43636735673751)

# %% [markdown]
# **AI Prompt**
#
# if weight doubles it means approx 14.4 cm increase in height?

# %% [markdown]
# **AI Response**
#
# Close! Let me help clarify the calculation.
#
# If weight doubles, log(weight) increases by ln(2) ≈ 0.693.
#
# With a slope of 47.07, the height increase would be:
# 47.07 × 0.693 ≈ 32.6 cm
#
# So when weight doubles, the model predicts about 33 cm increase in height.
#
# Does this make sense? Would you like to move on to creating the plot for part (b)?

# %%
sns.scatterplot(data=df, y='height', x='weight')
# Out:
# <Axes: xlabel='weight', ylabel='height'>

# %% [markdown]
# **AI Prompt**
#
# so I should do the sampling?

# %% [markdown]
# **AI Response**
#
# Yes! You need to sample from the posterior of your log-weight model and create predictions across the weight range.
#
# Since you're plotting against original weight (not log-weight), you'll need to:
# 1. Create a weight range
# 2. Convert to log-weight for the model predictions
# 3. Sample from the posterior to get intervals
#
# Would you like to start with creating the weight range, or would you prefer I show you the sampling setup?

# %%
weight_range=np.linspace(df.weight.min(), df.weight.max(), 100)

n_samples = 1000
posterior_samples = np.random.multivariate_normal(
    result_log .x, result_log .hess_inv, n_samples)


# Generate predictions for each weight
predictions_mean = []
predictions = []
for weight in weight_range:
    weight_predictions_mean = []
    weight_predictions = []
    for sample in posterior_samples:
        a, b, sigma = sample
        # Predicted mean
        mu = a + b * (np.log(weight) - xbar)
        pred = np.random.normal(mu, sigma)
        weight_predictions_mean.append(float(mu))
        weight_predictions.append(pred)
    predictions_mean.append(weight_predictions_mean)
    predictions.append(weight_predictions)

# Calculate 89% intervals
intervals_mean = []
for weight_preds in predictions_mean:
    lower = np.percentile(weight_preds, 5.5)
    upper = np.percentile(weight_preds, 94.5)
    mean_pred = np.mean(weight_preds)
    intervals_mean.append((mean_pred, lower, upper))

intervals = []
for weight_preds in predictions:
    lower = np.percentile(weight_preds, 5.5)
    upper = np.percentile(weight_preds, 94.5)
    mean_pred = np.mean(weight_preds)
    intervals.append((mean_pred, lower, upper))

means = [interval[0] for interval in intervals_mean]

# %%
ax=sns.scatterplot(data=df, x='weight', y='height')
plt.plot(weight_range, means)
lowers = [interval[1] for interval in intervals]
uppers = [interval[2] for interval in intervals]
lowers_mean = [interval[1] for interval in intervals_mean ]
uppers_mean = [interval[2] for interval in intervals_mean ]
plt.fill_between(weight_range, lowers, uppers, alpha=0.3)
plt.fill_between(weight_range, lowers_mean, uppers_mean, alpha=0.3)

# %% [markdown]
# **AI Prompt**
#
# is this ok solution?

# %% [markdown]
# **AI Response**
#
# Yes, that's a great solution! The log-weight model creates a nice curved relationship that fits the data much better than the linear model would.
#
# You can see how the logarithmic transformation captures the non-linear relationship - the curve is steeper for lighter individuals and flattens out for heavier ones, which makes biological sense.
#
# The intervals look appropriate too. How does this compare to what you observed with the linear model for children - does the log model seem to address some of those edge effect issues you noticed?

# %% [markdown]
# 4H4.  Plot the prior predictive distribution for the parabolic polynomial regression model in the chapter. You can modify the code that plots the linear regression prior predictive distribution. Can you modify the prior distributions of α, β1, and β2 so that the prior predictions stay within the biologically reasonable outcome space? That is to say: Do not try to fit the data by hand. But do try to keep the curves consistent with what you know about height and weight, before seeing these exact data.

# %%
# !pip install arviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.7 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/4.9 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 76.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/5 [h5py]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/5 [h5py]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 2/5 [xarray]
# ...

# %%
# !pip install pymc
# Out:
# ...
#   Preparing metadata (setup.py) ... -
# done
# ...
#   Preparing metadata (setup.py) ... -
# done
# ...
#   Preparing metadata (setup.py) ... -
# done
# ...
#   Preparing metadata (setup.py) ... -
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.0 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 45.2 MB/s eta 0:00:00
# ...
#   DEPRECATION: Building 'cons' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'cons'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
# \
# done
#   Created wheel for cons: filename=cons-0.4.6-py3-none-any.whl size=9098 sha256=abb9bebcace434e1ad7d2c32f0188ac585967476d642ab14d10ef410525f0d3f
# ...

# %%
#in book we have:
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import scipy.stats as stats


d = pd.read_csv('static/Howell1.csv', sep=';')
d["weight_std"] = (d.weight - d.weight.mean()) / d.weight.std()
d["weight_std2"] = d.weight_std**2

weight_m = np.vstack((d.weight_std, d.weight_std**2, d.weight_std**3))
weight_m 

with pm.Model() as m_4_6:
    a = pm.Normal("a", mu=178, sigma=100)
    b = pm.Normal("b", mu=0, sigma=10, shape=3)
    sigma = pm.Uniform("sigma", lower=0, upper=50)
    mu = pm.Deterministic("mu", a + pm.math.dot(b, weight_m))
    height = pm.Normal("height", mu=mu, sigma=sigma, observed=d.height.values)
    trace_4_6 = pm.sample(1000, tune=1000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# /app/data/.local/lib/python3.12/site-packages/pytensor/link/c/cmodule.py:2968: UserWarning: PyTensor could not link to a BLAS installation. Operations that might benefit from BLAS will be severely degraded.
# This usually happens when PyTensor is installed via pip. We recommend it be installed via conda/mamba/pixi instead.
# Alternatively, you can use an experimental backend such as Numba or JAX that perform their own BLAS optimizations, by setting `pytensor.config.mode == 'NUMBA'` or passing `mode='NUMBA'` when compiling a PyTensor function.
# For more options and details see https://pytensor.readthedocs.io/en/latest/troubleshooting.html#how-do-i-configure-test-my-blas-library
#   warnings.warn(
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a, b, sigma]
# /usr/local/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ...

# %%
trace_4_6
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> observed_data

# %% [markdown]
# **AI Prompt**
#
# prior is a, b and sigma. can I take them from the model or some ohter way?

# %% [markdown]
# **AI Response**
#
# Yes! You can extract the prior samples directly from your PyMC model. Since you've already run MCMC sampling, you have posterior samples, but for prior predictive simulation you need to sample from just the priors.
#
# You can do this by:
#
# 1. **Sample from the prior directly using PyMC:**
# ```python
# with m_4_6:
#     prior_samples = pm.sample_prior_predictive(1000)
# ```
#
# 2. **Or extract the prior distributions from your model and sample manually:**
# ```python
# # The priors from your model were:
# # a ~ Normal(178, 100)
# # b ~ Normal(0, 10) for each of the 3 coefficients
# # sigma ~ Uniform(0, 50)
# ```
#
# Which approach would you like to try first?

# %%
with m_4_6:
    prior_samples = pm.sample_prior_predictive(1000)
# Out:
# Sampling: [a, b, height, sigma]

# %%
prior_samples
# Out:
# Inference data with groups:
# 	> prior
# 	> prior_predictive
# 	> observed_data

# %% [markdown]
# **AI Prompt**
#
# how to plot prior predictive samples?

# %% [markdown]
# **AI Response**
#
# Perfect! You now have prior samples. To plot the prior predictive distribution, you can extract the parameter samples and create predictions over a range of weight values.
#
# Would you like to:
#
# 1. Plot some individual prior prediction curves to see the variety
# 2. Plot the range/envelope of all prior predictions
# 3. Both?
#
# For example, you could extract a few samples and plot their curves:
#
# ```python
# # Extract first few prior samples
# a_samples = prior_samples.prior.a.values[0, :10]  # First 10 samples
# b_samples = prior_samples.prior.b.values[0, :10]  # First 10 samples
# ```
#
# Which approach would you prefer to start with?

# %% [markdown]
# **AI Prompt**
#
# I have model in r: "d$weight_s3 <- d$weight_s^3
#
# m4.6 <- quap(
#
#  alist(
#
#   height ~ dnorm( mu , sigma ) ,
#
#   mu <- a + b1*weight_s + b2*weight_s2 + b3*weight_s3 ,
#
#   a ~ dnorm( 178 , 20 ) ,
#
#   b1 ~ dlnorm( 0 , 1 ) ,
#
#   b2 ~ dnorm( 0 , 10 ) ,
#
#   b3 ~ dnorm( 0 , 10 ) ,
#
#   sigma ~ dunif( 0 , 50 )
#
#  ) , data=d )" is this similar in python?

# %% [markdown]
# **AI Response**
#
# Yes, your PyMC model is very similar! The main differences are:
#
# **R model**: Uses `weight_s`, `weight_s2`, `weight_s3` (separate variables)
# **Your PyMC model**: Uses a matrix `weight_m` with all powers stacked
#
# Both have the same structure:
# - Cubic polynomial (3 terms)
# - Same priors for a, b coefficients, and sigma
# - Same likelihood (normal distribution)
#
# The key difference is that your PyMC model has `b ~ Normal(0, 10)` for all 3 coefficients, while the R model has `b1 ~ lognormal(0,1)` but `b2, b3 ~ Normal(0,10)`.
#
# Would you like to modify the priors to match exactly, or is this difference intentional?

# %% [markdown]
# **AI Prompt**
#
# I want to update python model to be same as in r

# %% [markdown]
# **AI Response**
#
# To match the R model exactly, you need to change the prior for `b[0]` (which corresponds to `b1` in R) from Normal to Lognormal.
#
# In your PyMC model, you currently have:
# ```python
# b = pm.Normal("b", mu=0, sigma=10, shape=3)
# ```
#
# Would you like me to show you how to modify this to have different priors for each coefficient, or would you prefer to try it yourself first?

# %% [markdown]
# **AI Prompt**
#
# show me

# %% [markdown]
# **AI Response**
#
# Here's how to modify the priors to match the R model:
#
# ```python
# b1 = pm.Lognormal("b1", mu=0, sigma=1)
# b2 = pm.Normal("b2", mu=0, sigma=10)
# b3 = pm.Normal("b3", mu=0, sigma=10)
# ```
#
# Then in your `mu` calculation, you'd need to change from:
# ```python
# mu = pm.Deterministic("mu", a + pm.math.dot(b, weight_m))
# ```
#
# to:
# ```python
# mu = pm.Deterministic("mu", a + b1*weight_m[0] + b2*weight_m[1] + b3*weight_m[2])
# ```
#
# Would you like to try implementing this change?

# %%
weight_m = np.vstack((d.weight_std, d.weight_std**2, d.weight_std**3))
weight_m 

with pm.Model() as m_4_6:
    a = pm.Normal("a", mu=178, sigma=100)
    b1 = pm.Lognormal("b1", mu=0, sigma=1)
    b2 = pm.Normal("b2", mu=0, sigma=10)
    b3 = pm.Normal("b3", mu=0, sigma=10)
    sigma = pm.Uniform("sigma", lower=0, upper=50)
    mu = pm.Deterministic("mu", a + b1*weight_m[0] + b2*weight_m[1] + b3*weight_m[2])
    height = pm.Normal("height", mu=mu, sigma=sigma, observed=d.height.values)
    trace_4_6 = pm.sample(1000, tune=1000)

# %%
with m_4_6:
    prior_samples = pm.sample_prior_predictive(1000)

# %% [markdown]
# **AI Prompt**
#
# am I doing prior sampling correctly?

# %%
a_samples = prior_samples.prior.a.values[0, :] 
b1_samples = prior_samples.prior.b1.values[0, :]  
b2_samples = prior_samples.prior.b2.values[0, :] 
b3_samples = prior_samples.prior.b3.values[0, :]

# %%
a_prior_hdi = az.hdi(a_samples, hdi_prob=0.97)
a_prior_hdi

# %%
b1_prior_hdi = az.hdi(b1_samples, hdi_prob=0.97)
b1_prior_hdi

# %%
a_samples
